# %% [markdown]
# ---
# # This cell contains abreviations that are used to display tooltips for the parameters names of PnET-Succession to make the documentation more readable. You can hide it if it is visible.
# abbreviations:
#     PnETSpeciesParameters: Parameter than then calls a list of species.
#     FolN: Foliar nitrogen content (in % by weight) for the leaves of the species.
#     SLWmax: Specific leaf weight at the top of the canopy.
#     SLWDel: Rate of change in the weight of the leaves from the top of the canopy (SLWmax) to each sublayer under the canopy.
#     MaxLAI: Maximum leaf area index (LAI) that a species can achieve in its lifetime (for an age cohort ?).
#     TOFol: Fraction of foliage biomass lost per year.
#     TORoot: Fraction of root biomass lost per year.
#     TOWood: Fraction of wood biomass lost per year.
#     AmaxA: Intercept of the relationship between foliar N and maximum net photosynthetic rate.
#     AmaxB: Slope of the relationship betwee foliar N and maximum net photosynthetic rate.
#     HalfSat: Half saturation light level for photosynthesis.
#     H1: Water stress parameter according to Feddes et al. (1978) (Fig. 59).
#     H2: Water stress parameter according to Feddes et al. (1978) (Fig. 59).
#     H3: Water stress parameter according to Feddes et al. (1978) (Fig. 59).
#     H4: Water stress parameter according to Feddes et al. (1978) (Fig. 59).
#     PsnAgeRed: Reduction factor of photosynthesis as the age of an age cohort increases.
#     LeafOnMinT: Minimum temperature for activate growing season.
#     PsnTMin: Minimum average daytime temperature for photosynthesis.
#     PsnTOpt: Optimal average daytime temperature for photosynthesis.
#     PsnTMax: Maximum average daytime temperature for photosynthesis.
#     ColTol: Cold tolerance (coldest temperature that the species can survive).
#     k (parameter): Canopy light attenuation constant (light extinction coefficient).
#     DNSC: Proportion of Non Structural (ressources) carbon from the total activate biomass of the cohort that will be maintained as long as net photosynthesis exceeds maintenance respiration.
#     FracBelowG: Fraction of non-foliar biomass that is allocated belowground (root pool).
#     EstMoist: Scaling parameter that changes the maximum expected value of fWater when computing the probability of establishment.
#     EstRad: Scaling parameter that changes the maximum expected value of fRad when computing the probability of establishment.
#     FracFol: Fraction of the active woody biomass (above or belowground) of a cohort that determines the amount of foliage maintained each year.
#     FrActWd: Shape parameter of the negative exponential function that calculates the amount of woody biomass that has active xylem capable of supporting foliage.
#     CO2HalfSatEff: Slope coefficient used to reduce HalfSat (= increase shade tolerance) as CO2 concentration increase.
#     CO2AMaxBEff: Proportional change in AmaxB at 550ppm CO2 relative to 350ppm.
#     O3StomataSens: Species susceptibility of the stomata to ozone-induced sluggishness.
#     O3GrowthSens: Species susceptibility to ozone-induced tissue damage.
#     MaxFolN: Controls the dynamic response of foliar nitrogen (FolN) to light.
#     FolNShape: Controls the dynamic response of foliar nitrogen (FolN) to light.
#     MaxFracFol: Controls the dynamic response of the fraction of Foliage (FracFol) to light.
#     FracFolShape: Controls the dynamic response of the fraction of Foliage (FracFol) to light.
#     LifeForm: Specifies the life form (stature) of the species to determine the limits to the species major canopy layer.
#     MossScalar: Unit converter from biomass to depth in the case of a pseudo species (moss).
#     MaxCanopyLayer: Caps the number of canopy layers implemented in the model.
#     LayerThreshRatio: Define how age cohorts of a given species are grouped together into canopy layers. Correspond to the minimum ratio of cohort woody biomass density between two cohorts that will place them in different canopy layers.
#     PARunits: Indicates the units for PAR and HalfSat values. See Climate Input File for PAR and Species Parameters File for HalfSat.
#     IMAX: Defines the degree of subdivision into different canopy sublayers for each age cohort.
#     DVPD1: Coefficient for converting the vapor pressure deficit (VPD) into a reduction factor for photosynthesis caused by water pressure (fDVPD).
#     DVPD2: Coefficient for converting the vapor pressure deficit (VPD) into a reduction factor for photosynthesis caused by water pressure (fDVPD).
#     BFolResp: Define the Base Foliar Respiration Fraction (the foliar respiration as a fraction of the maximum photosynthetic rate).
#     MaintResp: Represents the loss of Non Structural Carbon (NSC) due to maintenance respiration as a fraction of the active wood biomass of the cohort.
#     Q10: Coefficient of the Q10 relationship to compute the foliar respiration.
#     FolLignin: Mass fraction of lignin in foliage tissue.
#     KWdLit: Annual decomposition rate of woody litter (decay constant k in equations).
#     InitialNSC: Amount of Non Structural Carbon assigned to newly established cohorts.
#     CFracBiomass: Carbon fraction of biomass by weight in an age cohort.
#     PrecipEvents: Number of precipitation events during a month.
#     PrecipEventsWithReplacement: Defines the logic of assignation of the precipitation from a precipitation event to the canopy sub layers.
#     ETExtCoeff: Canopy extinction coefficient to reduce soil water evaporation as LAI increases (because of shadow created by the canopy ?).
#     RETCropCoeff: Coefficient that scales the reference evapotranspiration (RET).
#     PreventEstablishment: Turns species establishment on new cells on or off.
#     Wythers: Turns the Wythers correction on or off.
#     DTEMP: Turns the PnET-II DTEMP temperature reduction factor on or off.
#     MaxPest: Tuning parameter to raise or lower the establishment probability of species by a same proportion.
#     AmaxFrac: Fraction of the early morning instantaneous photosynthetic rate that represents the mean daily photosynthetic rate.
#     InvertPest: Activates the optional inversion of the effect of fRad on the probability establishment as a function of HalfSat.
#     SoilIceDepth: Activates the optional simulation of soil ice depth and its effects on water leakage.
#     LeakageFrostDepth: Soil ice depth at which frozen soil no longer impedes soil drainage.
#     FrostFactor: Tuning parameter to adjust soil ice depth.
#     InitialCommunitiesSpinup: Specifies how the biomass of the initial age cohorts/communities in each cells are generated.
#     SpinupWaterStress: Activates waterlogging stress during spin up procedures.
#     Parallel: Specifies the number of CPU threads used for parallel execution.
#     CohortStacking: Specifies the canopy cohort processing method.
#     CanopySumScale: Scales the degree to which cumulativve canopy proportions cannot exceed 1.
# ---

# %% [markdown]
# # Phase 1 🌳 : Calibration of species in optimal conditions (monoculture + mesic soil + average and unchanging climate)

# %% [markdown]
# ## Goal of this first calibration step
#
# The goal of this first calibration phase, as recommanded by [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf), is to calibrate the growth and mortality of a given tree species in "ideal" conditions. This means simulating a monoculture (no light competition with another species) on a mesic soil that retains water correctly (no drought, but no watterlogging either) and with a very mild, average historical climate (no extremes, especially in precipitations and temperatures).
#
# By doing so, we can isolate the effect of the many parameters and factor that influence tree growth, and focus on the few parameters that should (on a theoritical level) influence tree growth and mortality in ideal conditions :
#
# - FracFol
# - FolN
# - TOWood
# - TORoot
# - SLWmax
# - FracFol (pioneers species tend to have relatively high values)
# - FolN (pioneers species tend to have relatively high values)
# - FracBelowG
#
# To make sure your species sees the conditions of the simulation as really ideal (so that you can, again, isolate the effect from other parameters), you can even put PsnTOpt for your species to a value matching the climate inputs during the three warmest months of the growing season. This will make it so that your species sees the temperatures in your climate file as optimal. This is not absolutly necessary.
#
# WARNING HERE : I thought that we might want "optimal conditions in the study area"; but Gustafson seem to recommand "Optimal conditions for the species", because we are especially calibrating the amount of foliage the species will produce in its maximum growth ! See this :
#
# >
# > Calibrate all species under optimal temperature and precipitation conditions, which will result in growth reductions under other conditions. If you don’t uniformly calibrate species under optimal conditions, then their competition will be unrealistic and unpredictable during simulations. This is most easily done by using a fixed annual weather stream (long-term monthly averages), using typical monthly precipitation values. You should use growing season temperatures approximating PsnTOpt. This is most easily done by temporarily setting PsnTxxx values to match those of the climate inputs during the three warmest months of the growing season.
# >
# > Choose a single soil type for calibration of all species, preferably a soil type that is both common and highly productive. This enables you to estimate comparable life history trait parameters, ensuring that competition is realistic. Remember that you are not calibrating growth per se, but the FolN and foliage settings that will produce realistic growth under any set of abiotic conditions.
#
# Gustafson seems to especially indicate that this should be done for light (monospecific stand) and temperature (PsnTOpt). For water, he ackonwledge that there are limits :
#
# > Ultimately, monoculture growth is limited by water, so you want to calibrate under somewhat ideal conditions to reflect realistic
#
#
# Here, you will be trying to match a bit above the growth curves or estimates produced in your empirical data. This is become we're simulating ideal conditions, including a mild climate and a good soil (SILO). But in reality data, species do not grow in ideal conditions.
#
#
# :::{tip}
# Overall, as recommanded by the user guide, calibration is best done by modifying only FolN (to control relative productivity), FracFol, FrActWd and SLWmax (to control gross foliage amount and LAI, which determines the ability to access light) as much as possible. But if you produce growth curve that are too far from your empirical data, you can always change the other parameters too.
# :::
#
# :::{important}
# Be certain to have solid initial estimates for all other parameters that will not be calibrated during this phase, so as to avoid as much as possible a counfounding effect that could result from problematic or uncorrect values for these parameters.
# :::
#
# :::{important}
# Be certain to have good weather data. Because biomass accumulation is ultimately limited by water, your precipitation inputs should not be much greater than is typical for your study area, especially for the results of your simulation to match your empirical data better.
# :::
#
# :::{danger}
# As recommanded by [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf), keep in mind that calibrating growth to strictly match empirical growth curves may cause competition behavior in the model that is unrealistic. As such, you may want to favor a shape that is somewhat consistent with other species that have the same growth strategy (e.g., pioneers v. shade-tolerants). This will be important for the next phase (calibrating competition outcomes).
#
# Also keep in mind that *the model equations may produce a curve shape that is somewhat different than your empirical curves (likely generated under specific conditions) and forcing the model to exactly match empirical curves may reduce its validity in landscape simulations. In particular, you should try to match the biomass accumulation where growth begins to plateau and produce relative rates of initial growth that reflect each species’ growth strategy (i.e., continuum of pioneer v. shade-tolerant)*. ([Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf)).
# :::

# %% [markdown]
# ## How to do this step
#
# :::{important}
# Everything here comes from my interpretation of the calibration tips in [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf). These are quite complex, so there might be oversimplifications/misunderstanding from my part. I'll try to rectify if I detect some problems.
# :::
#
# ### Sub-phase 1 : Calibrating the peak
#
# Focusing on :
#
# - FracFol
# - FolN
# - TOWood
# - TORoot
# - SLWmax
# - FrActWd
#
# :::{important}
# During this phase, keep the value of MaxFracFol similar to FracFol. MaxFracFol will then be changed in the next phase.
# :::
#
# First, adjust TOWood/TORoot for large adjustments of the growth curve peak. The objective is to match a peak that is a bit above empirical data (around 5-10%) to account for the fact that we are simulating in ideal conditions, while empirical data is not in ideal conditions.
#
# Then, tune LAI towards realistic values via FracFol and TOWood/TORoot, and then SLWmax for fine tuning. The idea is to keep SLWmax within empirical limits. LAI will most likely not vary much after this. LAI is determined by two factors: the amount of foliage and the thickness of leaves (SLWmax). Thus, simultaneous tuning of foliage (FracFol, FrActWd) and leaf thickness (SLWmax) is required.
#
# If LAI empirical values are not avaibles, here are targets recommanded by [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) :
#
# | Shade Tolerance Category | Tolerant | Somewhat-tolerant | Intermediate | Somewhat intolerant | Intolerant |
# |:-:|:-:|:-:|:-:|:-:|:-:|
# | Maximum LAI Target | <5.0 | <4.5 | <3.5 | <2.8 | <2.5 |
#
# In any case, try to avoid LAI above 5.0.
#
# **The LAI should remain relatively stable after its peak**, meaning that you should monitor LAI. LAI will however decline when scenscence begins (fAge drops approximately below 0.6). Stability of the LAI is often dealt with the FrActWd parameter.
#
# After taking care of the LAI, FolN can then be used to modestly adjust the height of the entire growth curve for fine tuning. However, FolN should remain withing empirical limits as much as possible.
#
# For long-lived tree species that tend to get heart rot, large dead branches or lots of self-thinning mortality (e.g. red maple), raising TOWood can reduce the height of the growth curve with a correct reason to do so.
#
# If the amount of dead wood produced is too much, TOWood can be reduced with a concomitant increase in TORoot. Note that the biomass lost from wood becomes woody debris but biomass lost from roots just vaporizes (i.e., it is not tracked).
#
# :::{important}
# As per [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) : *If you have a curve that abnormally flattens after about year 50 after modifying some parameter other that MaintResp, it is likely because of lack of water, often caused by excess foliage that consumes water. Try reducing foliage (with FracFol and/or FracActWd) and increasing FolN to get a curve with a more gradually tapering shape. You’ll need to ensure that LAI stays within bounds for the species*.
# :::

# %%
## Calibration sub-sub-phase 1.1.1 : We change TORoot and TOWood to make large adjustments to
# the biomass peak, while keeping them in bounds. If we can't make larget adjusments to the biomass
# peak enough while staying in the bounds, we run diagnostics and display information to the user.

from functionsForCalibration import *


resultDict = {}

resultDict["ABIE.BAL"] = calibrate_phase1_1(
    species             = "ABIE.BAL",
    functional_type     = "evergreen",
    target_peak_biomass = 11799.949235,      # g/m² — from NFI data
    LAI_min             = 4,
    LAI_target          = 5,
    LAI_max             = 6,
    dictOfInitialCoreSpeciesParameters = json.load(
        open('./SpeciesParametersSets/Initial/initialCoreSpeciesParameters.json')),
    dictOfInitialPnETSpeciesParameters = json.load(
        open('./SpeciesParametersSets/Initial/initialPnETSpeciesParameters.json')),
    dictOfInitialPnETGenericParameters = json.load(
        open('./SpeciesParametersSets/Initial/InitialGenericParameters.json')),
    DictOfBounds        = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json"))
)


resultDict["ACER.RUB"] = calibrate_phase1_1(
    species             = "ACER.RUB",
    functional_type     = "deciduous",
    target_peak_biomass = 7955.82665,      # g/m² — from NFI data
    LAI_min             = 3.0,
    LAI_target          = 4.0,
    LAI_max             = 5.0,
    dictOfInitialCoreSpeciesParameters = json.load(
        open('./SpeciesParametersSets/Initial/initialCoreSpeciesParameters.json')),
    dictOfInitialPnETSpeciesParameters = json.load(
        open('./SpeciesParametersSets/Initial/initialPnETSpeciesParameters.json')),
    dictOfInitialPnETGenericParameters = json.load(
        open('./SpeciesParametersSets/Initial/InitialGenericParameters.json')),
    DictOfBounds        = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json"))
)


resultDict["PICE.MAR"] = calibrate_phase1_1(
    species             = "PICE.MAR",
    functional_type     = "evergreen",
    target_peak_biomass = 14808.317573,      # g/m² — from NFI data
    LAI_min             = 3.5,
    LAI_target          = 4.5,
    LAI_max             = 5.5,
    dictOfInitialCoreSpeciesParameters = json.load(
        open('./SpeciesParametersSets/Initial/initialCoreSpeciesParameters.json')),
    dictOfInitialPnETSpeciesParameters = json.load(
        open('./SpeciesParametersSets/Initial/initialPnETSpeciesParameters.json')),
    dictOfInitialPnETGenericParameters = json.load(
        open('./SpeciesParametersSets/Initial/InitialGenericParameters.json')),
    DictOfBounds        = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json"))
)

# Re-writing parameter dicts
dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/initialCoreSpeciesParameters.json'))
dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/initialPnETSpeciesParameters.json'))
dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Initial/InitialGenericParameters.json'))

for species in resultDict:
    dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species]["TOWood"] = resultDict[species]["TOWood"]
    dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species]["TORoot"] = resultDict[species]["TORoot"]

if os.path.exists("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1"):
    shutil.rmtree("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1")
os.mkdir("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1")

with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/initialCoreSpeciesParameters.json", "w") as f: json.dump(dictOfInitialCoreSpeciesParameters, f)
with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/initialPnETSpeciesParameters.json", "w") as f: json.dump(dictOfInitialPnETSpeciesParameters, f)
with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/InitialGenericParameters.json", "w") as f: json.dump(dictOfInitialPnETGenericParameters, f)
# Out:
# [PHASE 1.1] Species: ABIE.BAL
#   Target peak biomass : 11799.9 g/m²
#   LAI target range    : [4.0, 5.0, 6.0]
#
# [STEP 1] Baseline simulation  (TOWood=0.030000, TORoot=0.030000)
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
#   Baseline peak biomass : 10440.0 g/m²
#   Target peak biomass   : 11799.9 g/m²
#   Difference            : -1359.9 g/m²
#   Direction: baseline BELOW target → will DECREASE TOWood/TORoot
#
# [STEP 2] Feasibility check at limits (TOWood=0.004790, TORoot=0.018134)
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
#   Peak at limits: 16292.0 g/m²
#
# [STEP 3] Incremental search toward target...
# ...

# %%
## Calibration sub-sub-phase 1.1.2 : We calibrate and stabilize the LAI
# of the cohort to be within a range around the maximum LAI proposed by Gustafon
# in the user guide, by tweaking FracFol, SLWMax and FrActWood.

from functionsForCalibration import *

resultDict = {}

resultDict["ABIE.BAL"] = calibrate_LAI_subphase_1_1_2(
    "ABIE.BAL",
    target_LAI_min=4,
    target_LAI_max=5,
    DictOfBounds=json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    initial_core_params_path="./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/initialCoreSpeciesParameters.json",
    initial_pnet_species_params_path="./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/initialPnETSpeciesParameters.json",
    initial_generic_params_path="./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/InitialGenericParameters.json",
    duration=300,
    climate="mild",
    soil="SILO",
    n_bisection_iterations=20,
    verbose=True
)

resultDict["ACER.RUB"] = calibrate_LAI_subphase_1_1_2(
    "ACER.RUB",
    target_LAI_min=2.5,
    target_LAI_max=3.5,
    DictOfBounds=json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    initial_core_params_path="./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/initialCoreSpeciesParameters.json",
    initial_pnet_species_params_path="./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/initialPnETSpeciesParameters.json",
    initial_generic_params_path="./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/InitialGenericParameters.json",
    duration=300,
    climate="mild",
    soil="SILO",
    n_bisection_iterations=20,
    verbose=True
)

resultDict["PICE.MAR"] = calibrate_LAI_subphase_1_1_2(
    "PICE.MAR",
    target_LAI_min=3.5,
    target_LAI_max=4.5,
    DictOfBounds=json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    initial_core_params_path="./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/initialCoreSpeciesParameters.json",
    initial_pnet_species_params_path="./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/initialPnETSpeciesParameters.json",
    initial_generic_params_path="./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/InitialGenericParameters.json",
    duration=300,
    climate="mild",
    soil="SILO",
    n_bisection_iterations=20,
    verbose=True
)

# Re-writing parameter dicts
dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/initialCoreSpeciesParameters.json'))
dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/initialPnETSpeciesParameters.json'))
dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.1.1/InitialGenericParameters.json'))

for species in resultDict:
    dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species]["FracFol"] = resultDict[species]["final_params"]["FracFol"]
    dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species]["SLWmax"] = resultDict[species]["final_params"]["SLWmax"]
    dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species]["FrActWd"] = resultDict[species]["final_params"]["FrActWd"]

if os.path.exists("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.2"):
    shutil.rmtree("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.2")
os.mkdir("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.2")

with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/initialCoreSpeciesParameters.json", "w") as f: json.dump(dictOfInitialCoreSpeciesParameters, f)
with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/initialPnETSpeciesParameters.json", "w") as f: json.dump(dictOfInitialPnETSpeciesParameters, f)
with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/InitialGenericParameters.json", "w") as f: json.dump(dictOfInitialPnETGenericParameters, f)
# Out:
# === Stage 1: Coarse LAI adjustment via FracFol ===
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
#   FracFol=0.0400 -> Max LAI=3.511
#   FracFol=0.1100 -> Max LAI=8.367
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
#   Iter 1: FracFol=0.07500, Max LAI=5.6361
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
#   Iter 2: FracFol=0.05750, Max LAI=4.4129
# ...

# %%
## Subsubstep 1.1.3 : We're making a final adjustment to the growth peak after
# we dealt with the LAI in subsubstep 1.1.2 by tweaking FolN. The tweak should be modest,
# and FolN should stay within empirical values.

from functionsForCalibration import *


resultDict = {}

resultDict["ABIE.BAL"] = calibrate_subphase_1_1_3(
    species = "ABIE.BAL",
    target_peak_biomass = 11799.949235,   # g/m² — from NFI data
    DictOfBounds = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    path_core = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/initialCoreSpeciesParameters.json',
    path_pnet = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/initialPnETSpeciesParameters.json',
    path_generic = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/InitialGenericParameters.json',
    duration = 300,
    climate = "mild",
    soil = "SILO",
    tolerance = 0.01,
    max_iter = 50
)

resultDict["ACER.RUB"] = calibrate_subphase_1_1_3(
    species = "ACER.RUB",
    target_peak_biomass = 7955.82665,   # g/m² — from NFI data
    DictOfBounds = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    path_core = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/initialCoreSpeciesParameters.json',
    path_pnet = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/initialPnETSpeciesParameters.json',
    path_generic = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/InitialGenericParameters.json',
    duration = 300,
    climate = "mild",
    soil = "SILO",
    tolerance = 0.01,
    max_iter = 50
)

resultDict["PICE.MAR"] = calibrate_subphase_1_1_3(
    species = "PICE.MAR",
    target_peak_biomass = 14808.317573,   # g/m² — from NFI data
    DictOfBounds = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    path_core = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/initialCoreSpeciesParameters.json',
    path_pnet = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/initialPnETSpeciesParameters.json',
    path_generic = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/InitialGenericParameters.json',
    duration = 300,
    climate = "mild",
    soil = "SILO",
    tolerance = 0.01,
    max_iter = 50
)


# Re-writing parameter dicts
dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/initialCoreSpeciesParameters.json'))
dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/initialPnETSpeciesParameters.json'))
dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.1.2/InitialGenericParameters.json'))

for species in resultDict:
    dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species]["FolN"] = resultDict[species]

if os.path.exists("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.3"):
    shutil.rmtree("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.3")
os.mkdir("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.3")

with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/initialCoreSpeciesParameters.json", "w") as f: json.dump(dictOfInitialCoreSpeciesParameters, f)
with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/initialPnETSpeciesParameters.json", "w") as f: json.dump(dictOfInitialPnETSpeciesParameters, f)
with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/InitialGenericParameters.json", "w") as f: json.dump(dictOfInitialPnETGenericParameters, f)
# Out:
# [1.1.3] Species          : ABIE.BAL
# [1.1.3] Target biomass   : 11799.95 g/m²
# [1.1.3] FolN bounds      : [0.528, 2.189999999999999]
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
# [1.1.3] Baseline FolN    : 1.3000
# [1.1.3] Baseline peak    : 11669.00 g/m²  (relative error: 1.11%)
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
# [1.1.3] Biomass at FolN lower bound (0.5280): 4.00 g/m²
# [1.1.3] Biomass at FolN upper bound (2.1900): 21212.00 g/m²
#
# [1.1.3] Starting bisection...
# ...

# %% [markdown]
# ## Sub-phase 2 : Calibrating the beginning of the growth curve
#
# Focusing on :
#
# - MaxFracFol
# - FracFolShape
#
# The objective is to match the speed at which biomass accumulates towards the peak. This is crucial for competition further down the road, as species that can grow very fast will be more competitive.
#
# Two elements can be used as targets here : your empirical data, and the targets of Wood biomass at age 14 (in g/m2) recommanded by [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) :
#
# | Shade Tolerance Category | Tolerant | Somewhat-tolerant | Intermediate | Somewhat intolerant | Intolerant |
# |:-:|:-:|:-:|:-:|:-:|:-:|
# | Wood biomass at age 14 (g/m2) | 235 | 360 | 440 | 560 | 670 |
#
# To match these targets, it is recommanded that you act on these two parameters :
#
# MaxFracFol allow you to add foliage when a cohort is newly established when increasing it, which will speed up the growth curve towards its peak. One can put MaxFracFol to a value inferior to FracFol in the cases where a reduction in early growth is need to match the wood biomass target values of above. I'ts better to tweak MaxFracFol at this point rather than before sub-phase 1 to avoid back-and-forths. If even high values of MaxFracFol cannot give an adequate early growth, TOFol might need to be slightly lowered (happens for evergreen species with TOFol often around 0.5)
#
# Increasing FracFolShape will control the range of light levels over which an increase of foliage is produced. Its effect is more complex : increasing it will limit the response of LAI to high light conditions, while lowering it spreads the response over a greater range of light condition.
#
# Both MaxFracFol and FracFolShape are modifiers that adjust FracFol (the amount of foliage maintened each year by the cohort depending on the woody biomass of the cohort) depending on the level of light present. [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) thus recommand one approach to try to find the values of MaxFracFol and FracFolShape that will produce the desired value in FracFol given the light stress (fRad) at the beginning of the growing season and at a later year (near the biomass peak). However, I fail to understand how one would have "desired" values of FracFol. Still, FracFol is likely one of the most sensitive parameters of PnET-Succession (see [here](https://www.frontiersin.org/articles/10.3389/ffgc.2023.1020305)), so it's better to plan things ahead if possible.
#
# Remember that LAI will be capped via the calibration you did before in the step before; here, we are calibrating how quickly the gain of LAI is done at the beginning of a cohort's life, which influences the beginning of its growth curve.
#
# **NOTES AFTER WRITING THE FUNCTION**.
#
# Automatizing this step was the most difficult one so far. This is because of two big caveats :
#
# - The parameters tend to all interact with each other. Changing MaxFracFol changes the LAI, but changes it less if we increase FracFolShape; and increasing FrActWd tends decrease the LAI and increase the peak height and reduce the peak time, unless in some situations we affect the affectation of the cohort too much, and strange things starts to happen (e.g. enormous decrease in growth, or very irregular LAI, etc.).
# - There exists "holes" in the parameters space so that once we're inside of them, increasing a parameter in one direction leads to big problems. For examples, we can find ourselves in situations where decreasing FracFol doesn't decrease the LAI anymore, because its interaction with a MaxFracFol that is too high with a FracFolShape that is too low creates LAI spikes and very unnatural dynamics that mess up with the algorithm as it's trying to correct course. It's a bit like playing minigolf on a course where you have to follow a specific path to avoid your ball falling into pits that you must avoid.
#
# I had to deal with these two problems while trying to keep things relatively simple - meaning having simple phases we just increase/decrease one or two parameters at the same time to match a target. I wanted to avoid having a more complex algorithm that would explore the parameter space in a more complex way.
#
# In the end, the algorithm is in two phases : First, we try to find a combo of MaxFracFol and FracFolShape that 1. will get us closer to the peak timing and 2. will avoid making our cohort "fragile", meaning that it might create very irregular and strange dynamics of LAI because of how MaxFracFol works. This is done by increasing FracFolShape very quickly as MaxFracFol increases, as FracFolShape will reduce the effect of MaxFracFol to conditions where light is plentiful only as we increase it.
#
# Then, the algorithm will adjust FrActWd to change the peak timing; but every two iterations of adjustments, we re-adjust the peak height and the LAI so that they match what we had at the start. This is so that we don't put ourselves in a problematic situation where the LAI and the peak height become so absurdly large (or small) that our cohort simply cannot grow correctly anymore, which then messes up the algorithm as it tries to keep adjusting FrAcWd. By constantly adjusting, we might take a bit more time, but we're coming to it quite well in the end.
#
# There are several arbitrary values here : the amount by which we do increments on the different parameters, how fast FracFolShape changes with MaxFracFol, etc. All of these I've found through trial and error, especially as I was trying to calibrate the red maple - which according to the NFI data has a quite a quick peak time at 50 years, requiring a lot of adjustment.
#
# If the algorithm doesn't work for your species, you might have to use the advice above to find the right parameter set manually, by exploring the parameter space by yourself.

# %%
from functionsForCalibration import *

resultDict = {}

resultDict["ACER.RUB"] = calibrate_subphase_1_2(
    species = "ACER.RUB",
    target_peak_time = 49.986034,   # years (from NFI data)
    target_peak_biomass = 7955.82665,
    target_LAI = 3.5,
    DictOfBounds = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    path_core = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/initialCoreSpeciesParameters.json',
    path_pnet = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/initialPnETSpeciesParameters.json',
    path_generic = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/InitialGenericParameters.json',
    duration = 300,
    climate = "mild",
    soil = "SILO")

resultDict["ABIE.BAL"] = calibrate_subphase_1_2(
    species = "ABIE.BAL",
    target_peak_time = 68.645251,   # years (from NFI data)
    target_peak_biomass = 11799.949235,
    target_LAI = 5,
    DictOfBounds = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    path_core = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/initialCoreSpeciesParameters.json',
    path_pnet = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/initialPnETSpeciesParameters.json',
    path_generic = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/InitialGenericParameters.json',
    duration = 300,
    climate = "mild",
    soil = "SILO")

resultDict["PICE.MAR"] = calibrate_subphase_1_2(
    species = "PICE.MAR",
    target_peak_time = 114.287709,   # years (from NFI data)
    target_peak_biomass = 14808.317573,
    target_LAI = 4.5,
    DictOfBounds = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    path_core = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/initialCoreSpeciesParameters.json',
    path_pnet = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/initialPnETSpeciesParameters.json',
    path_generic = './SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/InitialGenericParameters.json',
    duration = 300,
    climate = "mild",
    soil = "SILO")


# Re-writing parameter dicts
dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/initialCoreSpeciesParameters.json'))
dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/initialPnETSpeciesParameters.json'))
dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.1.3/InitialGenericParameters.json'))

for species in resultDict:
    dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species]["MaxFracFol"] = resultDict[species]["MaxFracFol"]
    dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species]["FracFolShape"] = resultDict[species]["FracFolShape"]
    dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species]["FrActWd"] = resultDict[species]["FrActWd"]
    dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species]["FracFol"] = resultDict[species]["FracFol"]
    dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species]["TOWood"] = resultDict[species]["TOWood"]
    dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species]["TORoot"] = resultDict[species]["TORoot"]

if os.path.exists("./SpeciesParametersSets/Calibrated_SubSubPhase1.2"):
    shutil.rmtree("./SpeciesParametersSets/Calibrated_SubSubPhase1.2")
os.mkdir("./SpeciesParametersSets/Calibrated_SubSubPhase1.2")

with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.2/initialCoreSpeciesParameters.json", "w") as f: json.dump(dictOfInitialCoreSpeciesParameters, f)
with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.2/initialPnETSpeciesParameters.json", "w") as f: json.dump(dictOfInitialPnETSpeciesParameters, f)
with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.2/InitialGenericParameters.json", "w") as f: json.dump(dictOfInitialPnETGenericParameters, f)
# Out:
# ...
# Subphase 1.2 — Species: ACER.RUB
# ...
#
# [Baseline] Running baseline simulation...
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
#   Baseline peak time    : 136.5 yr
#   Baseline max LAI      : 3.7841
#   Baseline peak biomass : 8005.00 g/m²
#
# --- Phase A: Adjusting MaxFracFol (FracFolShape coupled) ---
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
#   [A-  1] MaxFracFol=0.0340  FracFolShape=8.0000 | PeakTime=81.5 yr | MaxLAI=4.6246
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
#   [A-  2] MaxFracFol=0.0540  FracFolShape=9.5891 | PeakTime=75.5 yr | MaxLAI=4.7322
# ...

# %% [markdown]
# ## Sub-phase 3 (optional) : Accelerating early growth for species that grow too slowly
#
# By calibrating the peak timing (sub-phase 2), it happens that some species do indeed get the right timing; but that they spents the first decades (sometimes up to 50 years) of their lives almost not growing at all.
#
# This seems to be the result of an overall lack of productivity for these species in their early years which translate to a low LAI, and vice versa. This lack of productivity/foliage can be caused by different things at once, like the species having a low productivity to begin with (low FolN), a combination of parameters that affects the LAI which make it difficult for the species to accumulate it in its early stages (FracFol, SLWMax, etc.), temperatures, etc.
#
# The problem is that if we try to change these parameters, we also affect the rest of the growth of the species; especially its biomass peak timing and peak height.
#
# I've tweaked a lot with different parameters to try to find something that would allow us to accelerate the early growth, while not moving the rest of the growth curve too much. It's quite difficult, especially if we need to really increase the early growth of species. The best parameters I've found are MaxFracFol/FracFolShape ; and MaxFolN/FolNShape. These are made to affect only the early growth; MaxFracFol and MaxFolN increase FracFol and FolN respectively, while FracFolShape and FolNShape reduce the effect of MaxFracFol and MaxFolN as the canopy closes (as fRad diminishes). These parameters have been added to the PnET-Succession code by Eric Gustafson for this exact goal (influencing the early growth but not the rest of the curve as much as possible). So here, we increase these parameters to make the early growth faster; and because we will change the rest of the curve anyway, we correct the LAI with SLWMax, we correct the peak timing with FolN, and then we correct the peak height with TOWood and TORoot again. It's really a game of jungling at this point. Hopefully, the steps after this one are easier to deal with.
#
# There remains the question of the target; how much do we want to increase the early growth of the species ? When do we stop ? I pondered about using another target, that we would call the "Biomass reached at 50% of the peak timing". We could extract this value from the NFI data and GAMs in notebook 4. But after trying to deal with this, I realize that for the Black spruce (`PICE.MAR`, which had a slower growth than necessary and which was the motivation for this step) demande too much adjustments to reach the right value of its biomass reached at 50% of the peak timing (as derived from NFI data). The model simply wouldn't go there without creating other big issues and pushing the parameters to extra high value. I've got some hypothesis as to why this might be; could be issues with the NFI data which overestimate early growth, or the fact that the parameters in the current PnET-Succession equation are too static and should change with the age of the cohort (i.e. the allocation of photosynthesis to the different part of the trees, or its turnover of wood and leaves, etc., are not the same when the tree is young versus when it gets old).
#
# So, I went with a simple rule that worked well in the case of the Black spruce : **the biomass reached at 50% of the peak timing should be at least 30% of the biomass peak height**. That's what this calibration step tries to ensure. For the rest, I leave my trust in the hands of the PnET model.
#
# :::{warning}
# The calibration algorithm used here is a bit simpler than the others because there are more parameters, and because I was running out of time. It might get stuck and overshoot its targets at some points. Be careful with it !
# :::

# %%
from functionsForCalibration import *

resultDict = {}

# Using a peak timing tolerance of 7 years seems OK to me; it's arbitrary, and you can change it if needed.
# If the tolerance is to low, this algorithm might have trouble reaching it though.

resultDict["ACER.RUB"] = calibrate_subphase_1_3(
    species = "ACER.RUB",
    target_peak_time = 49.986034,   # years (from NFI data)
    target_peak_biomass = 7955.82665,
    peak_time_tolerance = 7,
    target_LAI = 3.5,
    dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.2/initialCoreSpeciesParameters.json')),
    dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.2/initialPnETSpeciesParameters.json')),
    dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.2/InitialGenericParameters.json')),
    DictOfBounds = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    duration = 300,
    climate = "mild",
    soil = "SILO")

resultDict["ABIE.BAL"] = calibrate_subphase_1_3(
    species = "ABIE.BAL",
    target_peak_time = 68.645251,   # years (from NFI data)
    target_peak_biomass = 11799.949235,
    peak_time_tolerance = 7,
    target_LAI = 5,
    dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.2/initialCoreSpeciesParameters.json')),
    dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.2/initialPnETSpeciesParameters.json')),
    dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.2/InitialGenericParameters.json')),
    DictOfBounds = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    duration = 300,
    climate = "mild",
    soil = "SILO")

resultDict["PICE.MAR"] = calibrate_subphase_1_3(
    species = "PICE.MAR",
    target_peak_time = 114.287709,   # years (from NFI data)
    target_peak_biomass = 14808.317573,
    peak_time_tolerance = 7,
    target_LAI = 4.5,
    dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.2/initialCoreSpeciesParameters.json')),
    dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.2/initialPnETSpeciesParameters.json')),
    dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.2/InitialGenericParameters.json')),
    DictOfBounds = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    duration = 300,
    climate = "mild",
    soil = "SILO")


# Re-writing parameter dicts
dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.2/initialCoreSpeciesParameters.json'))
dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.2/initialPnETSpeciesParameters.json'))
dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.2/InitialGenericParameters.json'))

# Detect if MaxFolN/FolNShape have been used for one of the species
# If that's the case, we will provide values that disable their effect for other species who didn't need it,
# as all species need to have the parameter
MaxFolN_FolNShape_enabled = False
for species in resultDict:
    if "MaxFolN" in resultDict[species].keys() or "FolNShape" in resultDict[species].keys():
        MaxFolN_FolNShape_enabled = True
        break

if MaxFolN_FolNShape_enabled:
    for species in resultDict:
        if "MaxFolN" not in resultDict[species].keys() or "FolNShape" not in resultDict[species].keys():
            resultDict[species]["MaxFolN"] = dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species]["FolN"]
            resultDict[species]["FolNShape"] = 1

for species in resultDict:
    for parameter in ["MaxFracFol", "FracFolShape", "FracFol", "MaxFolN", "FolNShape", "FolN", "TOWood", "TORoot"]:
        if parameter in resultDict[species].keys() and resultDict[species][parameter] != "Parameter is not in dictionnary":
            dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species][parameter] = resultDict[species][parameter]

if os.path.exists("./SpeciesParametersSets/Calibrated_SubSubPhase1.3"):
    shutil.rmtree("./SpeciesParametersSets/Calibrated_SubSubPhase1.3")
os.mkdir("./SpeciesParametersSets/Calibrated_SubSubPhase1.3")

with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.3/initialCoreSpeciesParameters.json", "w") as f: json.dump(dictOfInitialCoreSpeciesParameters, f)
with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.3/initialPnETSpeciesParameters.json", "w") as f: json.dump(dictOfInitialPnETSpeciesParameters, f)
with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.3/InitialGenericParameters.json", "w") as f: json.dump(dictOfInitialPnETGenericParameters, f)
# Out:
# ...
# Subphase 1.3 — Accelerating early growth for: ACER.RUB
# ...
#
# [Step 1] Running baseline simulation...
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
#   Biomass at 50% of peak time : 4589.1500 g/m²
#   Peak biomass                : 8085.0000 g/m²
#   Peak time                   : 55.5 years
#   30% threshold (target)      : 2386.7480 g/m²
#
# [PASS] Species already reaches ≥30% of peak biomass at 50% of peak time.
# No calibration needed for Subphase 1.3. Returning current parameter values.
#
# ...
# Subphase 1.3 — Accelerating early growth for: ABIE.BAL
# ...
#
# [Step 1] Running baseline simulation...
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
#   Biomass at 50% of peak time : 6126.8000 g/m²
# ...

# %% [markdown]
# ## Sub-phase 4 : Senescence
#
# Focusing on :
#
# - PsnAgeRed
# - Longevity (LANDIS-II Core species parameter; is outside of PnET Succession)
#
# The last phase of the curve to calibrate is the senescence phase, where the tree cohort grows older. At it grows, its maintenance cost (in carbon) will grow; but its photosynthesis will be reduced through a reduction factor, and will completly stop as the cohort reaches the "longevity" core species parameter for its species. This is how tree cohort die of old age in PnET-Succession : by becoming progressively unable to sustain their maintenance costs through photosynthesis.
#
# As such, there are two targets that are being calibrated here : 1) the age where photosynthesis will start declining because of age, and 2) the age where the photosynthesis reduction factor will become so low that the cohort will die by lack of ressources. These two targets are shown on the following figure :
#
# <!-- This is a comment; I had to find a way to resize the image in Jupyter lab.
# That makes for a snippet a code that is more complex than I'd want. See https://github.com/jupyter/notebook/issues/1885. -->
# <nop/> <div style="width: 600px;">![image.png](attachment:06620d1a-3361-418f-a308-99f82342221b.png)</div>
#
# The first target (initiation of decline) is defined in PnET with the parameter PsnAgeRed, which controls when the photosynthesis reduction factor fAge starts declining, and how fast.
#
# The second target (age of cohort death) is influenced by the start of the decline (first target), but also  with the "longevity" parameter given in the "Core" species parameter file (e.g. `species.txt` in `/SimulationFiles/\PnETGitHub_OneCellSim_v8`). When the age of the cohort reaches the "longevity" parammeter, the photosynthesis reduction factor fAge will reach 0 (no more photosynthesis takes place). Of course, the cohort will most likely die before it reaches 0 because its photosynthesis will have been too low for too much time, which will have depleted its ressources before fAge reaches 0. As such, you should try to input a "longevity" parameter value in the species parameter file that will kill your cohort at the age you want (e.g. that correspond to empirical data) in interaction with your first target. Note again that the cohort will very likely die **before** the longevity parameter.
#
# As to where you can get estimates of these two targets (initation of decline and age of cohort death) for your species, this gets a bit complex. The decreasing part of the empirical biomass growth data that you might have used so far often contain the effect of other factors that affect tree morality including human harvesting, natural disturbance and diseases, and competition with other trees. However, as we are simulating tree growth in ideal conditions, we are trying to isolate the effect of senescence from these other factors. As such, the empirical biomass data you have will most likely not be a good target to match (as you will over-estimate senescence if you try to match them).
#
# As such, there are several options to get the initiation of decline and age of cohort death. Here are some of them :
#
# - For the age of cohort death, you could try to obtain individual tree age data from sample plots of forest inventory, and find the 99th percentile (to avoid outlayers) of tree age for your species. This should give you a good estimate of the maximum age observed for this species, which should be as close as can be to something like a "age of cohort death in ideal growth conditions" as we're trying to find here.
#     - Be careful of the reported values in the litterature for the longevity of the species. These are often expert opinion, and might represent what experts often see in the field, which is influenced by other causes of mortality (competition, climate, disturbances, etc.) that you don't want to take into account here.
# - For the initiation of decline, you can :
#     - Use reported values of longevity in the litterature, which are often the result of rule-of-thumb or expert opinion as noted above, but which can be interpreted as the initiation of decline; for the age of cohort death, you could rather use empirical values of maximum tree age (see above). This is the methodology used by Brian Sturtevant's team.
#     - Take a percentile of the tree ages from the same tree age data you used for the age of cohort death (see above); for example, 75th or 80th percentile.
#     - Use a rule-of-thumb and set the initiation of decline to half or 3/4 of the age of cohort death.
#     - Use the default value of PsnAgeRed in PnET (5), or the same value for every species. [Gustafson and Miranda (2023)](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) actually recommand against calibrating PsnAgeRed for every species, on the basis that it will make it harder to understand and calibrate the competition between species (see next step).
#
# :::{warning}
# If you have depressed the growth curve using PsnAgeRed in the previous sub-phase 3, then you should't change it at this step, and should rather focus in changing the value of longevity in the core species parameter file so that the age of cohort death is correct.
# :::
#
# **TO UPDATE ?? :** In this notebook, we will use the 99th percentile of empirical tree age data in Canada from sample plot data to set the age of cohort death for our species, and we will use the default value of PsnAgeRed (5) to set the initiation of decline.

# %%
from functionsForCalibration import *

resultDict = {}

resultDict["ACER.RUB"] = calibrate_senescence(
    species = "ACER.RUB",
    typical_mortality = 80, # TYPMORT from Loehle
    maximum_mortality = 150, # MAXMORT from Loehle
    target_peak_biomass = 7955.82665,
    DictOfBounds = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    path_core='./SpeciesParametersSets/Calibrated_SubSubPhase1.3/initialCoreSpeciesParameters.json',
    path_pnet='./SpeciesParametersSets/Calibrated_SubSubPhase1.3/initialPnETSpeciesParameters.json',
    path_generic='./SpeciesParametersSets/Calibrated_SubSubPhase1.3/InitialGenericParameters.json',
    tolerance=3,
    max_iterations=50,
    simulation_duration=500,
    climate="mild",
    soil="SILO")

resultDict["ABIE.BAL"] = calibrate_senescence(
    species = "ABIE.BAL",
    typical_mortality = 125, # TYPMORT from Loehle
    maximum_mortality = 150, # MAXMORT from Loehle
    target_peak_biomass = 11799.949235,
    DictOfBounds = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    path_core='./SpeciesParametersSets/Calibrated_SubSubPhase1.3/initialCoreSpeciesParameters.json',
    path_pnet='./SpeciesParametersSets/Calibrated_SubSubPhase1.3/initialPnETSpeciesParameters.json',
    path_generic='./SpeciesParametersSets/Calibrated_SubSubPhase1.3/InitialGenericParameters.json',
    tolerance=3,
    max_iterations=50,
    simulation_duration=500,
    climate="mild",
    soil="SILO")

resultDict["PICE.MAR"] = calibrate_senescence(
    species = "PICE.MAR",
    typical_mortality = 150, # TYPMORT from Loehle
    maximum_mortality = 250, # MAXMORT from Loehle
    target_peak_biomass = 14808.317573,
    DictOfBounds = json.load(open("./SpeciesParametersSets/SpeciesParameterBounds.json")),
    path_core='./SpeciesParametersSets/Calibrated_SubSubPhase1.3/initialCoreSpeciesParameters.json',
    path_pnet='./SpeciesParametersSets/Calibrated_SubSubPhase1.3/initialPnETSpeciesParameters.json',
    path_generic='./SpeciesParametersSets/Calibrated_SubSubPhase1.3/InitialGenericParameters.json',
    tolerance=3,
    max_iterations=50,
    simulation_duration=500,
    climate="mild",
    soil="SILO")

# Re-writing parameter dicts
dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.3/initialCoreSpeciesParameters.json'))
dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.3/initialPnETSpeciesParameters.json'))
dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.3/InitialGenericParameters.json'))

for species in resultDict:
    for parameter in ["PsnAgeRed", "TOWood", "TORoot"]:
        dictOfInitialPnETSpeciesParameters["PnETSpeciesParameters"][species][parameter] = resultDict[species][parameter]
    dictOfInitialCoreSpeciesParameters[species]["Longevity"] = str(resultDict[species]["Longevity"])
if "PsnAgeRed" in dictOfInitialPnETGenericParameters.keys(): del dictOfInitialPnETGenericParameters["PsnAgeRed"]

if os.path.exists("./SpeciesParametersSets/Calibrated_SubSubPhase1.4"):
    shutil.rmtree("./SpeciesParametersSets/Calibrated_SubSubPhase1.4")
os.mkdir("./SpeciesParametersSets/Calibrated_SubSubPhase1.4")

with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.4/initialCoreSpeciesParameters.json", "w") as f: json.dump(dictOfInitialCoreSpeciesParameters, f)
with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.4/initialPnETSpeciesParameters.json", "w") as f: json.dump(dictOfInitialPnETSpeciesParameters, f)
with open("./SpeciesParametersSets/Calibrated_SubSubPhase1.4/InitialGenericParameters.json", "w") as f: json.dump(dictOfInitialPnETGenericParameters, f)
# Out:
# ...
# Subphase 1.4 – Senescence calibration for ACER.RUB
# ...
#   Target typical mortality (initiation of decline) : 80.0 years
#   Target maximum mortality (time of death)         : 150.0 years
#   Target peak biomass                              : 7955.83 g/m²
#   Tolerance                                        : ±3 years
#
#   [Init] PsnAgeRed = 2.5558
#   [Init] Longevity  = 227.27 years
#   [Init] Analytical initiation of decline = 92.32 years (target: 80.0)
#
#   [Iter 1] PsnAgeRed = 2.5558 | Longevity = 227.27
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
#            → Simulated time of death         : 200.0 years (target: 150.0)
#            → Simulated initiation of decline : 92.0 years (target: 80.0)
#            → Longevity adjustment: -25.00 → new Longevity = 202.27
#            → Recomputed PsnAgeRed = 2.4824
#
# ...

# %% [markdown]
# ## Checking final growth curve versus NFI/GAM growth curves

# %%
from functionsForCalibration import *


calibrationSimulationMonoculturemanawan(duration = 300,
                                        climate = "mild",
                                        soil = "SILO",
                                        speciesToSimulate = "ABIE.BAL",
                                        dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/initialCoreSpeciesParameters.json')),
                                        dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/initialPnETSpeciesParameters.json')),
                                        dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Initial/InitialGenericParameters.json')),
                                        plotResults = False,
                                       saveGrowthCurvePath = "./SpeciesParametersSets/Checkup_Step1/ABIE.BAL_Growth_PnET_initial.csv")

calibrationSimulationMonoculturemanawan(duration = 300,
                                        climate = "mild",
                                        soil = "SILO",
                                        speciesToSimulate = "ABIE.BAL",
                                        dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.4/initialCoreSpeciesParameters.json')),
                                        dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.4/initialPnETSpeciesParameters.json')),
                                        dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.4/InitialGenericParameters.json')),
                                        plotResults = False,
                                       saveGrowthCurvePath = "./SpeciesParametersSets/Checkup_Step1/ABIE.BAL_Growth_PnET.csv")

plot_growth_curves("./ReferencesAndData/Growth Curves Predictions/Abies balsamea_gam_predictions.csv",
                   "./SpeciesParametersSets/Checkup_Step1/ABIE.BAL_Growth_PnET.csv",
                  "ABIE.BAL",
                  "./SpeciesParametersSets/Checkup_Step1/ABIE.BAL_Growth_PnET_initial.csv")

calibrationSimulationMonoculturemanawan(duration = 300,
                                        climate = "mild",
                                        soil = "SILO",
                                        speciesToSimulate = "ACER.RUB",
                                        dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/initialCoreSpeciesParameters.json')),
                                        dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/initialPnETSpeciesParameters.json')),
                                        dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Initial/InitialGenericParameters.json')),
                                        plotResults = False,
                                       saveGrowthCurvePath = "./SpeciesParametersSets/Checkup_Step1/ACER.RUB_Growth_PnET_initial.csv")

calibrationSimulationMonoculturemanawan(duration = 300,
                                        climate = "mild",
                                        soil = "SILO",
                                        speciesToSimulate = "ACER.RUB",
                                        dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.4/initialCoreSpeciesParameters.json')),
                                        dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.4/initialPnETSpeciesParameters.json')),
                                        dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.4/InitialGenericParameters.json')),
                                        plotResults = False,
                                       saveGrowthCurvePath = "./SpeciesParametersSets/Checkup_Step1/ACER.RUB_Growth_PnET.csv")

plot_growth_curves("./ReferencesAndData/Growth Curves Predictions/Acer rubrum_gam_predictions.csv",
                   "./SpeciesParametersSets/Checkup_Step1/ACER.RUB_Growth_PnET.csv",
                  "ACER.RUB",
                  "./SpeciesParametersSets/Checkup_Step1/ACER.RUB_Growth_PnET_initial.csv")

calibrationSimulationMonoculturemanawan(duration = 300,
                                        climate = "mild",
                                        soil = "SILO",
                                        speciesToSimulate = "PICE.MAR",
                                        dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/initialCoreSpeciesParameters.json')),
                                        dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Initial/initialPnETSpeciesParameters.json')),
                                        dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Initial/InitialGenericParameters.json')),
                                        plotResults = False,
                                       saveGrowthCurvePath = "./SpeciesParametersSets/Checkup_Step1/PICE.MAR_Growth_PnET_initial.csv")

calibrationSimulationMonoculturemanawan(duration = 300,
                                        climate = "mild",
                                        soil = "SILO",
                                        speciesToSimulate = "PICE.MAR",
                                        dictOfInitialCoreSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.4/initialCoreSpeciesParameters.json')),
                                        dictOfInitialPnETSpeciesParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.4/initialPnETSpeciesParameters.json')),
                                        dictOfInitialPnETGenericParameters = json.load(open('./SpeciesParametersSets/Calibrated_SubSubPhase1.4/InitialGenericParameters.json')),
                                        plotResults = False,
                                       saveGrowthCurvePath = "./SpeciesParametersSets/Checkup_Step1/PICE.MAR_Growth_PnET.csv")

plot_growth_curves("./ReferencesAndData/Growth Curves Predictions/Picea mariana_gam_predictions.csv",
                   "./SpeciesParametersSets/Checkup_Step1/PICE.MAR_Growth_PnET.csv",
                  "PICE.MAR",
                  "./SpeciesParametersSets/Checkup_Step1/PICE.MAR_Growth_PnET_initial.csv")


plot_multispecies_growth_curves(
    ["./ReferencesAndData/Growth Curves Predictions/Abies balsamea_gam_predictions.csv",
    "./ReferencesAndData/Growth Curves Predictions/Acer rubrum_gam_predictions.csv",
    "./ReferencesAndData/Growth Curves Predictions/Picea mariana_gam_predictions.csv"],
    ["./SpeciesParametersSets/Checkup_Step1/ABIE.BAL_Growth_PnET.csv",
     "./SpeciesParametersSets/Checkup_Step1/ACER.RUB_Growth_PnET.csv",
     "./SpeciesParametersSets/Checkup_Step1/PICE.MAR_Growth_PnET.csv"
    ],
    ["ABIE.BAL",
     "ACER.RUB",
     "PICE.MAR"
    ]

)
# Out:
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
# Launching LANDIS-II simulation with command : /bin/bash -c "cd /tmp/monocultureCalibrationPnET/ && dotnet $LANDIS_CONSOLE scenario.txt"
# The LANDIS-II simulation has finished properly!
# ...
