# %% [markdown]
# ---
# # This cell contains abreviations that are used to display tooltips for the parameters names of PnET-Succession to make the documentation more readable. You can hide it if it is visible.
# abbreviations:
#     PnETSpeciesParameters: Parameter than then calls a list of species.
#     FolN: Foliar nitrogen content (in % by weight) for the leaves of the species.
#     SLWmax: Specific leaf weight at the top of the canopy.
#     SLWDel: Rate of change in the weight of the leaves from the top of the canopy (SLWmax) to each sublayer under the canopy.
#     MaxLAI: Maximum leaf area index (LAI) that a species can achieve in its lifetime (for an age cohort ?).
#     TOFol: Fraction of foliage biomass lost per year.
#     TORoot: Fraction of root biomass lost per year.
#     TOWood: Fraction of wood biomass lost per year.
#     AmaxA: Intercept of the relationship between foliar N and maximum net photosynthetic rate.
#     AmaxB: Slope of the relationship betwee foliar N and maximum net photosynthetic rate.
#     HalfSat: Half saturation light level for photosynthesis.
#     H1: Water stress parameter according to Feddes et al. (1978) (Fig. 59).
#     H2: Water stress parameter according to Feddes et al. (1978) (Fig. 59).
#     H3: Water stress parameter according to Feddes et al. (1978) (Fig. 59).
#     H4: Water stress parameter according to Feddes et al. (1978) (Fig. 59).
#     PsnAgeRed: Reduction factor of photosynthesis as the age of an age cohort increases.
#     LeafOnMinT: Minimum temperature for activate growing season.
#     PsnTMin: Minimum average daytime temperature for photosynthesis.
#     PsnTOpt: Optimal average daytime temperature for photosynthesis.
#     PsnTMax: Maximum average daytime temperature for photosynthesis.
#     ColTol: Cold tolerance (coldest temperature that the species can survive).
#     k (parameter): Canopy light attenuation constant (light extinction coefficient).
#     DNSC: Proportion of Non Structural (ressources) carbon from the total activate biomass of the cohort that will be maintained as long as net photosynthesis exceeds maintenance respiration.
#     FracBelowG: Fraction of non-foliar biomass that is allocated belowground (root pool).
#     EstMoist: Scaling parameter that changes the maximum expected value of fWater when computing the probability of establishment.
#     EstRad: Scaling parameter that changes the maximum expected value of fRad when computing the probability of establishment.
#     FracFol: Fraction of the active woody biomass (above or belowground) of a cohort that determines the amount of foliage maintained each year.
#     FrActWd: Shape parameter of the negative exponential function that calculates the amount of woody biomass that has active xylem capable of supporting foliage.
#     CO2HalfSatEff: Slope coefficient used to reduce HalfSat (= increase shade tolerance) as CO2 concentration increase.
#     CO2AMaxBEff: Proportional change in AmaxB at 550ppm CO2 relative to 350ppm.
#     O3StomataSens: Species susceptibility of the stomata to ozone-induced sluggishness.
#     O3GrowthSens: Species susceptibility to ozone-induced tissue damage.
#     MaxFolN: Controls the dynamic response of foliar nitrogen (FolN) to light.
#     FolNShape: Controls the dynamic response of foliar nitrogen (FolN) to light.
#     MaxFracFol: Controls the dynamic response of the fraction of Foliage (FracFol) to light.
#     FracFolShape: Controls the dynamic response of the fraction of Foliage (FracFol) to light.
#     LifeForm: Specifies the life form (stature) of the species to determine the limits to the species major canopy layer.
#     MossScalar: Unit converter from biomass to depth in the case of a pseudo species (moss).
#     MaxCanopyLayer: Caps the number of canopy layers implemented in the model.
#     LayerThreshRatio: Define how age cohorts of a given species are grouped together into canopy layers. Correspond to the minimum ratio of cohort woody biomass density between two cohorts that will place them in different canopy layers.
#     PARunits: Indicates the units for PAR and HalfSat values. See Climate Input File for PAR and Species Parameters File for HalfSat.
#     IMAX: Defines the degree of subdivision into different canopy sublayers for each age cohort.
#     DVPD1: Coefficient for converting the vapor pressure deficit (VPD) into a reduction factor for photosynthesis caused by water pressure (fDVPD).
#     DVPD2: Coefficient for converting the vapor pressure deficit (VPD) into a reduction factor for photosynthesis caused by water pressure (fDVPD).
#     BFolResp: Define the Base Foliar Respiration Fraction (the foliar respiration as a fraction of the maximum photosynthetic rate).
#     MaintResp: Represents the loss of Non Structural Carbon (NSC) due to maintenance respiration as a fraction of the active wood biomass of the cohort.
#     Q10: Coefficient of the Q10 relationship to compute the foliar respiration.
#     FolLignin: Mass fraction of lignin in foliage tissue.
#     KWdLit: Annual decomposition rate of woody litter (decay constant k in equations).
#     InitialNSC: Amount of Non Structural Carbon assigned to newly established cohorts.
#     CFracBiomass: Carbon fraction of biomass by weight in an age cohort.
#     PrecipEvents: Number of precipitation events during a month.
#     PrecipEventsWithReplacement: Defines the logic of assignation of the precipitation from a precipitation event to the canopy sub layers.
#     ETExtCoeff: Canopy extinction coefficient to reduce soil water evaporation as LAI increases (because of shadow created by the canopy ?).
#     RETCropCoeff: Coefficient that scales the reference evapotranspiration (RET).
#     PreventEstablishment: Turns species establishment on new cells on or off.
#     Wythers: Turns the Wythers correction on or off.
#     DTEMP: Turns the PnET-II DTEMP temperature reduction factor on or off.
#     MaxPest: Tuning parameter to raise or lower the establishment probability of species by a same proportion.
#     AmaxFrac: Fraction of the early morning instantaneous photosynthetic rate that represents the mean daily photosynthetic rate.
#     InvertPest: Activates the optional inversion of the effect of fRad on the probability establishment as a function of HalfSat.
#     SoilIceDepth: Activates the optional simulation of soil ice depth and its effects on water leakage.
#     LeakageFrostDepth: Soil ice depth at which frozen soil no longer impedes soil drainage.
#     FrostFactor: Tuning parameter to adjust soil ice depth.
#     InitialCommunitiesSpinup: Specifies how the biomass of the initial age cohorts/communities in each cells are generated.
#     SpinupWaterStress: Activates waterlogging stress during spin up procedures.
#     Parallel: Specifies the number of CPU threads used for parallel execution.
#     CohortStacking: Specifies the canopy cohort processing method.
#     CanopySumScale: Scales the degree to which cumulativve canopy proportions cannot exceed 1.
#     Eric Gustafson: Former researcher (now retired) at the US Forest Service. Eric was largely responding for develloping the PnET-Succession extension of LANDIS-II.
#     Brian Sturtevant: Researcher at the US Forest Service. Has worked extensively with PnET-Succession and assisted in its development.
# ---

# %% [markdown]
# # Getting the empirical data needed fo the calibration process

# %% [markdown]
# Here, I catalog the other data needed for the calibration process, in addition to the initial parameters (see [here](./3.Initial_Species_Parameters.ipynb) for the parameters) and to the climate and soil data used in the simulations for the calibration (see [here](./4.Setting_up_calibration_Landscape.ipynb) for soil and climate data).
#
# This other data will be used to :
#
# - Target values to match during the calibration (e.g. biomass growth curves)
# - Determine the value of some parameters directly (e.g. maximum longevity)
# - Establish ranges of parameter values in which we should remain during the calibration
# - Expected outcomes of simulations (e.g. competition outcomes, climate change outcomes, etc.)
#
# I will write here as much suggestions a possible for future researchers that will want to calibrate for their own research or study area, but I will also indicate what I will be using in these notebooks.

# %% [markdown]
# ## Empirical data for biomass growth curves.
#
# This is an essential part of the calibration process, especially the first step in which we will calibrate each species in "ideal" conditions of growth (mild climate, good soil water retention, etc.). These "ideal" conditions are important to isolate the effect of other parameters and other sources of mortality, so that we can focus on the basic parameters of growth and senescence for your species (see [the first calibration step](./6.Monoculture_ideal_conditions.ipynb)).
#
# Basically, what you want is data that allows you to infer a biomass growth curve for each given species, showing the evolution of the biomass of a cohort for the species in conditions that are as ideal as possible.
#
# As of today, I've ran accross three different strategies to get this data. I'll describe them in the following sections.
#
# ### Option 1 : Sample plot data.
#
# By looking at individual tree data from sample plot data, you can infer tree biomass and tree age, making each tree measurement or plot measurement a point on your graph.
#
# By looking at the points that are at the top of the cloud of points that will result, you can get and idea of the maximum biomass a tree can reach for a given age, which should give you good information about the growth curve. This is a method used by many research so far.
#
# The problem is that sample plot data is often messy, full of outliers, biases, needing sharing agrements, etc. As such, it will require important work to clean, and several important assumptions will influence your results enormously. For example, the "tree age" data is often missing, and you'll have to infer it from DBH; and you'll also have to choose how to translate your individual tree biomass into biomass/surface (as all LANDIS-II biomass output is interpreted in biomass/surface, not biomass/tree).
#
# This data can still be quite useful to derive certain caractestics of the growth curve (e.g. the age of the peak of growth for a given species).
#
# In Canada, aquiring sample plot data has been very much facilitated by the publication of the [MAGPlot database](https://open.canada.ca/data/en/dataset/8824392d-464e-413d-8bde-eaed61c79743). It contains standardized and unified plot data accross all canadian provinces, with tree DBH as the best measure available at the plot level. Some of the data (e.g. plot coordinates) are randomized to preserve sensible information.
#
# ### Option 2 : Tree growth models.
#
# These models are complex equations develloped by foresters, industries or governmental agencies to try and predict growth or yield for different species in different conditions. These are often calibrated based on sample plot data; as such, the work of cleaning/dealing with sample plot data is often done for you. An example is the famous [Forest Vegetation Simulator](www.fs.usda.gov/fvs/) from the USDA. Other such models are simply growth curves published in the litterature, sometimes in books.
#
# The curves produced by these models are often in biomass/surface, which makes things easier to compare with LANDIS-II outputs than sample plot. You can also tweak the parameters of these models so that they predict biomass growth in conditions as ideal as possible, making it close to what you're looking for.
#
# The main issue is that these models can still produce pretty unrealistic curves; might not be available for your study area/region; and might still need parameters derived from sample plot data (e.g. Site index and maximum basal area for FVS). So while they can make your life simpler, they can still be difficult to use.
#
# FVS can be compiled into a Dockerfile and use in Python; I've tried it at first and will keep the functions that I've written in a separate document for you to re-use if necessary.
#
# Be warned that the decreasing part of the curves produced by these often often don't include mortality by senescence, which can make the cruve growth forever, making it difficult to identify the biomass peak which is very important for calibration purposes.
#
# Tree growth models have been used by several research teams, including Brian Sturtevant's and Eric Gustafson (the latter being the author of the calibration tips for PnET-Succession that are the basis of these documents).
#
# ### Option 3 : Forest inventory data.
#
# Some forest inventories contain data that allow you to infer tree or stand age and the biomass of your species of interest. For example, the [National Forest Inventory of Canada](https://nfi.nfis.org/en/) proposes raster maps of several forest attributes Canada-wide, including pixel/stand forest age, and the biomass of each individual species that are considered in the forest inventory.
#
# If you use each pixel from the maps of a single year as a point and plot a cloud of points on a biomass/time axis, you might get a good estimation of a growth curve, with a growth peak and a initial growth (the two most important parts in our case). This is, in essence, a ["space-for-time" substitution](https://link.springer.com/chapter/10.1007/978-1-4615-7358-6_5), where you look at many different points in space that will be forests at different stages of growth, rather than looking at the long-term history of a few forests.
#
# The big limitation of this data is that you often get one "stand age" or "pixel age" value per pixel, rather than a separate age value for the trees of a given species in the pixel. As such, in a pixel of 80 years, you cannot know if the biomass of species X comes from trees that are 80 years old, or if these trees are younger. But you can interpret the upper points of the cloud of points as "the maximum biomass that a species can reach for this stand age", which is pretty close to the mark of what you're looking for.
#
# Another big limitation is that in most pixels (if not all), your species will be mixed with other species. This is especially true if you are calibrating a "companion" species (the type of tree species that is never abundant, but yet found in many forests). You can restrict the points of your data to only the pixels where more than 50% of the biomass comes from your species of interest; but you might not get enough points for some rarer species. In these case, you will probably need to develop a correction of biomass to try and have an estimate of the biomass that your species can reach when it composes 100% of the stand. You might do this by making a statistical model that attempts to predict the biomass of your species in a stand or pixel based on the age of the pixel, and the % of composition of the species. You might want to train your statistic model on only the top percentile of points (as you're looking out for the most biomass your species can achieve for a given age).
#
# This data is often generated through a combination of forest inventory sampling (aerial photography, etc.) and sample plot data (which are assignated to stand or pixels via assignation algorithms like the kNN method). As such, it often contains information from sample plots, but which has already been cleaned and dealt with.
#
# The biomass data is often expressed in biomass/surface, making it easy to compare to LANDIS-II outputs.
#
# This is the data I will be using here. From what I heard, other teams have been using such data in the past.

# %% [markdown]
# :::{tip} What is the spatial extent for which I should take growth data for the calibration ? And what climate data should I use depending on the origin of my growth data ?
#
# See [the introductory notebook about some important notions before beginning the calibration](./0.1.Some_important_notions.ipynb) for detailed answers.
# :::

# %% [markdown]
# :::{tip} What data should I use to calibrate variants, like southern variants that are more adapted to heat ? And what variant I am calibrating for if I use this methodology ?
#
# See [the introductory notebook about some important notions before beginning the calibration](./0.1.Some_important_notions.ipynb) for detailed answers.
# :::

# %% [markdown]
# ### Option used here : data from the National Forest Inventory of Canada
#
# After investigation, and since my own use case is to calibrate PnET-Succession for several landscapes in Canada, I've chosen to go with option 3 (Forest inventory data). More specifically, I' m going to use the NFI (National Forest Inventory of Canada).
#
# See :
# - [https://nfi.nfis.org/en/](https://nfi.nfis.org/en/) for general information and visualisation of some of the maps
# - [https://open.canada.ca/data/en/dataset/ec9e2659-1c29-4ddb-87a2-6aced147a990](https://open.canada.ca/data/en/dataset/ec9e2659-1c29-4ddb-87a2-6aced147a990) to download the maps
# - [https://cdnsciencepub.com/doi/10.1139/cjfr-2017-0184](https://cdnsciencepub.com/doi/10.1139/cjfr-2017-0184) for details about how the maps were generated.
#
# Here, I'm using data from the most recent year (2011). I'm using the map `/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Stand_Age_v1.tif` for the stand (pixel) ages; `/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Biomass_TotalLiveAboveGround_v1.tif` for biomass of stands; and a series of rasters like `/NFI_Data/NFI_MODIS250m_2011_kNN_Species_Abie_Bal_v1.tif` that indicate the propotion of `/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Biomass_TotalLiveAboveGround_v1.tif` that corresponds to the species of interest (e.g. *Abies balsamea* in that case). All maps are currently in `./ReferencesAndData`.
#
# I'm also using several "mask" rasters to restrict or differenciate the pixel data from different provinces in Canada (e.g. `quebecMask.tif`, etc., all in `./ReferencesAndData`).

# %% [markdown]
# #### Investigating the data for Canada
#
# Here, before we use this dataset, I quickly show how it looks like by focusing on the highest points of the point clouds that it produces. Focusing on these highest points will give us an idea of the "best growth" that the species can achieve through by looking at different pixels from the same year throughout all of Canada.

# %%
# We read data from the NFI for our free species, and plot the distribution of the points above 95% of the maximum value in
# each 3 years window (which allows us to keep the top points)
from functionsForCalibration import *
import matplotlib.pyplot as plt


# We define the path to where the rasters are
species_path = "./ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Species_Abie_Bal_v1.tif"
age_path = "./ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Stand_Age_v1.tif"
biomass_path = "./ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Biomass_TotalLiveAboveGround_v1.tif"
# We define the paths to the mask rasters for each province
dictOfMasks = {"NS":"./ReferencesAndData/SpatialBoundaries/novaScotiaMask.tif",
              "QC":"./ReferencesAndData/SpatialBoundaries/quebecMask.tif",
              "ON":"./ReferencesAndData/SpatialBoundaries/ontarioMask.tif",
              "MT":"./ReferencesAndData/SpatialBoundaries/manitobaMask.tif",
              "SK":"./ReferencesAndData/SpatialBoundaries/saskatchewanMask.tif",
              "AB":"./ReferencesAndData/SpatialBoundaries/albertaMask.tif",
              "BC":"./ReferencesAndData/SpatialBoundaries/britishColumbiaMask.tif",}

plottingNFISpeciesUpperBiomassByProvince(species_path,
                                         age_path,
                                         biomass_path,
                                         "Abies balsamea",
                                         dictOfMasks)
# Out:
# Reading species raster...
# Reading age raster...
# Reading biomass raster...
# Dealing with NS
# Dealing with QC
# Dealing with ON
# Dealing with MT
# Dealing with SK
# Dealing with AB
# Dealing with BC

# %% [markdown]
# As such, we can see that :
#
# - The NFI data shows some pretty clear growth patterns (initial growth, peak, senescence)
# - We see that the different provinces can have very different growth peaks and initial growth/senescence. Upon closer inspection (plotting again but only for points with at least 50% of biomass composed of *Abies balsamea*), it seems to mostly be due to the differences in the mixture/competition of the species in difference province. SK, AB, MT and BC don't have many points where *Abies balsamea* is dominant. Meanwhile, NS, QC and ON have a lot of it.
#
# Now, here are the same figures for the other species :

# %%
# We define the path to where the rasters are
species_path = "./ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Species_Acer_Rub_v1.tif"
age_path = "./ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Stand_Age_v1.tif"
biomass_path = "./ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Biomass_TotalLiveAboveGround_v1.tif"

plottingNFISpeciesUpperBiomassByProvince(species_path,
                                         age_path,
                                         biomass_path,
                                         "Acer rubrum",
                                         dictOfMasks)
# Out:
# Reading species raster...
# Reading age raster...
# Reading biomass raster...
# Dealing with NS
# Dealing with QC
# Dealing with ON
# Dealing with MT
# Dealing with SK
# Dealing with AB
# Dealing with BC

# %%
# We define the path to where the rasters are
species_path = "./ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Species_Pice_Mar_v1.tif"
age_path = "./ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Stand_Age_v1.tif"
biomass_path = "./ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Biomass_TotalLiveAboveGround_v1.tif"

plottingNFISpeciesUpperBiomassByProvince(species_path,
                                         age_path,
                                         biomass_path,
                                         "Picea mariana",
                                         dictOfMasks)
# Out:
# Reading species raster...
# Reading age raster...
# Reading biomass raster...
# Dealing with NS
# Dealing with QC
# Dealing with ON
# Dealing with MT
# Dealing with SK
# Dealing with AB
# Dealing with BC

# %% [markdown]
# ### Producing estimated growth curves in ideal conditions (in Canada) for our species with NFI data using a Generalized Additive Model

# %% [markdown]
# #### Why we are using a Generalized Additive Model to produce estimates of growth curves in ideal conditions
#
# Based on the NFI data shown and explored in the previous section, we now have to produce estimated growth curves based on this data that we will be able to use as a "target" for the first step of the calibration of PnET-Succession, where we will try to match the curves produced by PnET-Succession with the data.
#
# Since the first calibration step is based on growth curves in "ideal" conditions, where the species we are calibrating have no competition for water and for light, we especially have to estimate the growth curves for monospecific stands, where the relative abundance of the species is 100%. Unfortunatly, pixels that contains only one species are very rare in the NFI rasters since the pixels are 250x250m, and also because in nature, monospecific stands can be quite rare for many species. Even worse, some species have a very low amount of pixels in which they have a high relative abundance, or even none at all. A good example here is *Acer rubrum*, the red maple, which has a low amount of points with relative abondance above 50% when compared to the two other species we are calibrating here, *Abies balsamea* and *Picea mariana*. I expect that many other tree species available in the NFI will have the same issue.
#
# As such, I propose to use statistical modelling to use the information contained in the pixels we do have (where the relative abundance of any given species is below 100%) in order to generate growth curves for different level of abundances, and especially for a 100% abundance. I set up to use Generalized Additive Models, as they model non-linear effects of variables quite well, and because I expect the effect of the factors that will be used in this model (forest age and relative species abundance) will be non-linear.
#
# In this approach, we will treat every pixel from the NFI raster as a single data point associated with 3 variables, one for the different raster : age of the pixel; biomass of the species X in the pixel; and relative abundance (in %) of species X in the pixel. By grouping these points into age windows, we can then use a GAM to predict the upper percentile of biomass of species X observed for a given age window, and for a given % relative abundance. As such, by predicting the upper percentile per age window, the GAM will predict how much maximal biomass species X can achieve for a given age, and a given % relative abundance.
#
# Once the GAM is fitted, we make predictions for a 100% relative abundance, which is what we want. These predictions will not be perfect, as very few (if none) pixels with a 100% relative abundance exist, as said before; and as such, the model will be extrapolating outside of the data on which it has been fitted. But whatever the approach we use (i.e. using the FVS model, or using sample plot data), the problem will be the same : as monospecific stands are rarely observed in nature, any estimate that we're trying to get here will be based on an extrapolation one way or another. This is the limitation of using a first calibration step in "ideal conditions", although using this approach has some great advantages. For more about this, take a look at [0.1.Some_important_notions.ipynb](./0.1.Some_important_notions.ipynb) where this question is talked about in details.
#
# Having these GAMs fitted will thus allow us to produce growth curves predicted by the GAM for different level of % relative abundance for the species X, including the 100% curve that we are looking for.

# %% [markdown]
# #### Methodology : using GAMs on pre-treated data from the NFI, and selecting the most realistic curve produced for the most limited spatial extent of data
#
# I've made some first attempts fitting some relatively simple GAMs on the data of the NFI for the three species I'm calibrating here. Unfortunatly, this didn't go well : the growth curves produced by the GAM was quite non-sensical, and didn't fit the points very well. I'm not an expert in statistics, but I expect that this was because the model being fitted on patterns within the data that I couldn't see with my human eyes (as in my eyes, the growth pattern visible in the data was quite clear). Maybe it's the overabundance of low-abundance pixels, and also the presence of some high-abundance pixels with relatively low biomass values and other outliers tended to create unexpected and absurd GAM behaviour.
#
# I solved this issue by pre-processing the data (see figure below) to 1) reduce the number of points, 2) remove the outliers, and 3) force a monotonic increasing rule regarding the effect of abundance of the high percentiles of biomass. This pre-processing is done by defining windows of age and % relative abundance; in each of these windows, we gather all of the pixels/points that are inside of it (i.e. pixels with an age and a % relative abundance for species X that have the value for the window); and then, we compute the upper percentile of biomass for the pixels/points in this window. We repeat the process accross all age/% relative abondance windows possible (without superposing the windows).
#
# Furthermore, the function can remove points that break the monotonic increasing tendancy of the effect of the abundance on the biomass; i.e. if a percentile for an abundance window of 80 is lower than the percentile of the previous abundance window (e.g. 75) for the same age window, we will not take it into account. This is done to clarify the tendancy of the effect of the abundance on the biomass to help the GAMs fit better on the data, using the assumption that points that do not follow this tendancy are deemed to be errors or extremes.
#
# Here is an depiction of the procedure in visual form :
#
# ![](./Images/GAM_DataProessing_NFI_Method.PNG)
#
# This pre-processing is highly customizible, allowing you to define the size of the windows, the percentile computed, or to exclude certain pixels; see the function `createPercentilesBiomassDatasetsFromNFIData` in `functionsForCalibration.py` . You can put the argument `printPlot` as `True` in order to see the resulting points datasets.
#
# The function `createPercentilesBiomassDatasetsFromNFIData` will generate four points datasets that correspond to four different spatial extent where we take the data from the NFI : the study landscape we are calibrating for; the ecozones that directly intersect with the study landscapes; the same ecozones + the ones that surrounds them in Canada; and finally, all of the data from the NFI for all of Canada. This is done so that we can fit GAMs and produce estimated growth curves for these different spatial extents, in order to compare the curves we obtain. The goal will be to select a curve that seems as realistic as possible while trying to select data as close to the study landscape as possible, in order to avoid mixing a lot of intra-specific variability (different phenotypes, variants, etc.) from the species in our dataset. However, sometimes, the data from the study landscape will not be enough to produce realistic curves, because there is not enough data points for the species in it (especially points with enough % relative abundance for the species).
#
# As such, the function `getGamDiagnostics` (used after `createPercentilesBiomassDatasetsFromNFIData`) will compute some diagnostic values for the 100% abundance curves produced by the GAMs fitted on each of these datasets, and then use a simple algorithm to determine the best curve, and export it to a `.csv` file where it can be used in the subsequent notebooks for the calibration. The selection is made by first determining which curves are considered "valid" according to three diagnostics : a pseudo R2 > 0.85; a curve shape that is truly concave; and a percentage of negative biomass values along the curve (for the entire age range of the curve) being inferior to 20%. Then, we simply select the first valid curve in the subset of points that is the smallest (i.e. closest to the study landscape), in order to reduce the intra-specific variability present in the subset of points on which our estimation is based.

# %% [markdown]
# #### The GAM equation we will use here
#
# The most robust GAM structure I've found after many trials accross the data for the three species we're calibrating here is the following. It's a GAM structure that produces mostly relatistic curves (e.g. curves that are concave, with clearly defined growth peaks, and start near 0) accross all species and data subsets (e.g. study landscape, ecozone, surrounding ecozones, and Canada).
#
# $\text{High Biomass Percentile} = s(age, by(\% abundance), \text{with a concave constraint}) +  s(\% abundance, by(age), \text{with a concave constraint}) + s(age, \text{with a concave constraint}) + s(\% abundance, \text{with a concave constraint})$
#
# Here, the `by` statement indicates a simple interaction between the two factors (see [the documentation of the pyGAM package](https://pygam.readthedocs.io/en/latest/notebooks/tour_of_pygam.html)). We can also use a more complex interaction using a tensor (`te()`), but all of my attempts using tensors resulted in curves that didn't make sense. It seems that the tensor was too sensitive to missing data, and tended to dip quickly into a negative effect, leading to non-sensical curves.

# %% [markdown]
# #### Producing and selecting a growth curve for Abies balsamea

# %%
from functionsForCalibration import *

speciesName = "Abies balsamea"

dictOfPointsSubsets = createPercentilesBiomassDatasetsFromNFIData(abundance_raster_path = './ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Species_' + str(speciesName.split()[0][0:4]) + '_'+ str(speciesName.split()[1][0:3].capitalize()) + '_v1.tif',
                                                                    age_raster_path = './ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Stand_Age_v1.tif',
                                                                    biomass_raster_path = './ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Biomass_TotalLiveAboveGround_v1.tif',
                                                                    speciesName = speciesName,
                                                                    study_landscape_shp_path = "./ReferencesAndData/SpatialBoundaries/ManawanTerritoryExtent.shp",
                                                                    canadian_ecozones_shp_path = "./ReferencesAndData/SpatialBoundaries/canadianEcozones.shp",
                                                                    age_window = 5,
                                                                    abundance_window = 5,
                                                                    percentile = 100,
                                                                    mask_path = None,
                                                                    printPlot = True)
# Out:
# Creating initial dataframes for each mask...
# Dealing with mask : study_landscape
#
# Creating windowed dataframe...
# Applied monotonic abundance constraint - kept 191 entries
# Dealing with mask : ecozone
#
# Creating windowed dataframe...
# Applied monotonic abundance constraint - kept 490 entries
# Dealing with mask : surrounding_ecozones
#
# Creating windowed dataframe...
# Applied monotonic abundance constraint - kept 519 entries
# Dealing with mask : canada
#
# Creating windowed dataframe...
# Applied monotonic abundance constraint - kept 559 entries
#
# ...

# %%
gamDiagnostics = getGamDiagnostics(dictOfPointsSubsets,
                                    speciesName,
                                    exportCsvOfSelectedCurve_Path = "./ReferencesAndData/Growth Curves Predictions/" + str(speciesName) + "_gam_predictions.csv",
                                    printPlot = True,
                                  dictionnaryOfSelectedCurves = "./ReferencesAndData/Growth Curves Predictions/dictOfSelectedCurvesSubsets.json")
# Out:
# ...
# GAM 100% Abundance Curve Diagnostics
# ...
#
# Columns 1-4:
#                      Pseudo_R2   Peak_Age  Peak_Biomass Pct_Negative_Biomass
# Mask
# study_landscape       0.988492  68.645251  11799.949235                 17.8
# ecozone               0.947505  67.863128   9738.222199                  0.6
# surrounding_ecozones  0.951891  67.863128   9633.716778                  0.0
# canada                0.938925  69.958101   9688.808445                  0.0
# --------------------------------------------------------------------------------
#
# Columns 5-8:
#                      Concavity_Pct_Decrease Is_Truly_Concave Max_Observed_Biomass Pct_Above_40_Abundance
# Mask
# study_landscape                  158.090472             True          7918.022949              14.659686
# ecozone                           39.631836             True         11690.157227              32.857143
# surrounding_ecozones              54.105954             True         11690.157227              31.984586
# ...

# %% [markdown]
# #### Producing and selecting a growth curve for Acer rubrum

# %%
from functionsForCalibration import *

speciesName = "Acer rubrum"

dictOfPointsSubsets = createPercentilesBiomassDatasetsFromNFIData(abundance_raster_path = './ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Species_' + str(speciesName.split()[0][0:4]) + '_'+ str(speciesName.split()[1][0:3].capitalize()) + '_v1.tif',
                                                                    age_raster_path = './ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Stand_Age_v1.tif',
                                                                    biomass_raster_path = './ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Biomass_TotalLiveAboveGround_v1.tif',
                                                                    speciesName = speciesName,
                                                                    study_landscape_shp_path = "./ReferencesAndData/SpatialBoundaries/ManawanTerritoryExtent.shp",
                                                                    canadian_ecozones_shp_path = "./ReferencesAndData/SpatialBoundaries/canadianEcozones.shp",
                                                                    age_window = 5,
                                                                    abundance_window = 5,
                                                                    percentile = 100,
                                                                    mask_path = None,
                                                                    printPlot = True)
# Out:
# Creating initial dataframes for each mask...
# Dealing with mask : study_landscape
#
# Creating windowed dataframe...
# Applied monotonic abundance constraint - kept 118 entries
# Dealing with mask : ecozone
#
# Creating windowed dataframe...
# Applied monotonic abundance constraint - kept 177 entries
# Dealing with mask : surrounding_ecozones
#
# Creating windowed dataframe...
# Applied monotonic abundance constraint - kept 208 entries
# Dealing with mask : canada
#
# Creating windowed dataframe...
# Applied monotonic abundance constraint - kept 251 entries
#
# ...

# %%
gamDiagnostics = getGamDiagnostics(dictOfPointsSubsets,
                                    speciesName,
                                    exportCsvOfSelectedCurve_Path = "./ReferencesAndData/Growth Curves Predictions/" + str(speciesName) + "_gam_predictions.csv",
                                    printPlot = True,
                                  dictionnaryOfSelectedCurves = "./ReferencesAndData/Growth Curves Predictions/dictOfSelectedCurvesSubsets.json")
# Out:
# ...
# GAM 100% Abundance Curve Diagnostics
# ...
# did not converge
# did not converge
#
# Columns 1-4:
#                      Pseudo_R2   Peak_Age Peak_Biomass Pct_Negative_Biomass
# Mask
# study_landscape       0.978342  46.298883  6992.664858                 35.0
# ecozone               0.983036  49.986034   7955.82665                 62.2
# surrounding_ecozones  0.987314  47.192737  4825.652195                 71.7
# canada                0.977551  43.002793  4665.314495                 72.8
# --------------------------------------------------------------------------------
#
# Columns 5-8:
#                      Concavity_Pct_Decrease Is_Truly_Concave Max_Observed_Biomass Pct_Above_40_Abundance
# Mask
# study_landscape                  552.181671             True          3421.385254                    0.0
# ecozone                          578.146999             True          5182.414551               1.694915
# ...

# %% [markdown]
# #### Producing and selecting a growth curve for Picea mariana

# %%
from functionsForCalibration import *

speciesName = "Picea mariana"

dictOfPointsSubsets = createPercentilesBiomassDatasetsFromNFIData(abundance_raster_path = './ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Species_' + str(speciesName.split()[0][0:4]) + '_'+ str(speciesName.split()[1][0:3].capitalize()) + '_v1.tif',
                                                                    age_raster_path = './ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Stand_Age_v1.tif',
                                                                    biomass_raster_path = './ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Biomass_TotalLiveAboveGround_v1.tif',
                                                                    speciesName = speciesName,
                                                                    study_landscape_shp_path = "./ReferencesAndData/SpatialBoundaries/ManawanTerritoryExtent.shp",
                                                                    canadian_ecozones_shp_path = "./ReferencesAndData/SpatialBoundaries/canadianEcozones.shp",
                                                                    age_window = 5,
                                                                    abundance_window = 5,
                                                                    percentile = 100,
                                                                    mask_path = None,
                                                                    printPlot = False)
# Out:
# Creating initial dataframes for each mask...
# Dealing with mask : study_landscape
#
# Creating windowed dataframe...
# Applied monotonic abundance constraint - kept 283 entries
# Dealing with mask : ecozone
#
# Creating windowed dataframe...
# Applied monotonic abundance constraint - kept 538 entries
# Dealing with mask : surrounding_ecozones
#
# Creating windowed dataframe...
# Applied monotonic abundance constraint - kept 615 entries
# Dealing with mask : canada
#
# Creating windowed dataframe...
# Applied monotonic abundance constraint - kept 647 entries
#
# ...

# %%
gamDiagnostics = getGamDiagnostics(dictOfPointsSubsets,
                                   speciesName,
                                  exportCsvOfSelectedCurve_Path = "./ReferencesAndData/Growth Curves Predictions/" + str(speciesName) + "_gam_predictions.csv",
                                  printPlot = False,
                                  dictionnaryOfSelectedCurves = "./ReferencesAndData/Growth Curves Predictions/dictOfSelectedCurvesSubsets.json")
# Out:
# ...
# GAM 100% Abundance Curve Diagnostics
# ...
#
# Columns 1-4:
#                      Pseudo_R2    Peak_Age  Peak_Biomass Pct_Negative_Biomass
# Mask
# study_landscape       0.980698   82.053073   9880.387691                  3.9
# ecozone               0.978313  114.287709  14808.317573                  0.0
# surrounding_ecozones  0.978437  121.773743  14815.123172                  0.0
# canada                0.968238  212.583799  16124.203155                  0.0
# --------------------------------------------------------------------------------
#
# Columns 5-8:
#                      Concavity_Pct_Decrease Is_Truly_Concave Max_Observed_Biomass Pct_Above_40_Abundance
# Mask
# study_landscape                   11.636732             True         10507.347656              35.335689
# ecozone                           53.371283             True         15191.075195              37.360595
# surrounding_ecozones              40.656132             True         15191.075195              38.536585
# ...

# %% [markdown]
# #### Comparing the peak of the biomass curves obtained with GAMs with the curves from Tompalski et al. 2025

# %% [markdown]
# The article from [Tompalski et al. 2025](https://doi.org/10.1093/forestry/cpaf067) proposes stand-level yield curves (e.g. evolution of the biomass through the aging of a stand) for stands dominated by a particular tree species (27 species available). The curves have been created using different sources of remote sensing and aerial laser data. Furthermore, these curves are develloped inside 150x150km tiles accross Canada, with one curve per tile (as long as enough data for a given species was available in the tile).
#
# We can use the data from the article, which is freely available in a very useful R package (see [ptompalski/RSYC](https://github.com/ptompalski/RSYC)), in order to assess the estimates we have obtained with the GAMs.
#
# :::{warning}
# Keep in mind that the biomass curves produced by Tompalski et al. 2025 are made with a different methodology than what we're doing here. In particular, their curves represent the biomass of a stand **dominated** by a given species; but they don't seem to remove the biomass from other species that will be inside the stand with the dominating species. Here, thanks to the NFI relative abundance raster, we do isolate the biomass for a given species. As such, species that can be dominant but which are still often not "very dominant" (not a lot of % relative biomass) will have their biomass mixed in with other species in the curves of Tompalski et al. 2025. This makes it that the curves of Tompalski et al. 2025 will often have higher biomass peaks than what is computed here for a given species; especially for species which display a low relative abondance accross most of their pixel because they are often companion species, like *Acer rubrum*.
#
# Also, the curves of Tompalski et al. 2025 often display no scenescence/decrease in biomass, because they focus on the stand level and not on the species in the stand. Meanwhile, or method based on the NFI data does track the scenescence of given species inside a stand more easily, since we can isolate the biomass from the species of interest.
# :::

# %% [markdown]
# The following function will use the dictionnary `dictOfSelectedCurvesSubsets.json` created in the previous steps, which contains the point subset that has been select for each species during the previous section. Then, it will retrieve the tiles from Tompalski et al. 2025 that intersect with the spatial extent of the subset (from `RSYC_tiles.gpkg` that is available on [ptompalski/RSYC](https://github.com/ptompalski/RSYC)), and then will retrieve the maximum biomass observed accross all tiles (already extracted into a .csv file named `species_max_biomass_TompalskiEtAl2025.csv` using the R script `extractingMaximalBiomassFromTompalskiEtAl2025.R`; we had to use an R script R since [ptompalski/RSYC](https://github.com/ptompalski/RSYC) is a R package).
#
# Finally, the function displays a bar plot showing the difference for each species between the biomass peak we got with the GAMs versus the average peak across all tiles intersecting the spatial extent used for the GAM in the curves of Tompalski et al. 2025. **The black bar on the top of the Tompalski et al. bar shows the minimum and maximum observed accross the model for all available tiles; it's not the standard deviation.**

# %%
from functionsForCalibration import *

compare_biomass_models(study_landscape_shp_path = "./ReferencesAndData/SpatialBoundaries/ManawanTerritoryExtent.shp",
                       ecozones_shp_path = "./ReferencesAndData/SpatialBoundaries/canadianEcozones.shp",
                       Tompalski_tiles_gpkg_path = "./ReferencesAndData/Growth Curves Predictions/RSYC_tiles.gpkg")
# Out:
# Processing Abies balsamea...
# Processing Acer rubrum...
# Processing Picea mariana...
# Processing complete!

# %% [markdown]
# As we can see, the maximum biomass observed in Tompalski et al. 2025 agrees quite well with the GAM for *Abies balsamea*  and *Picea Mariana*. However, the GAMs give a much lower estimates in our case for *Acer rubrum*. My own interpretation is that because the methodology of Tompalski et al. makes growth curves for "stands dominated by a given species"; as such, the biomass of their curves also contains the biomass of trees other than the dominant one. Here, we're isolating the biomass of each species from the one of other species completely, thanks to the relative abundance raster of the NFI. Because *Acer rubrum* is most often a companion species with a relatively low dominance (even when it is dominant in a stand), I expect that this curves from Tompalski et al. are much higher because they tend to contain the biomass of other species, while ours focuses on *Acer rubrum*.
#
# As such, I'll keep going with what the GAMs have generated here.

# %% [markdown]
# #### Limitations of the approach with GAMs to estimate growth in ideal conditions

# %% [markdown]
# The approach used here has a lot of advantages (replicable, using open-source and peer-reviewed datasets that are easily available, can be adapted to future datasets of the same format, etc.). But it also have important limitations. In particular, two things have to be kept in mind :
#
# - We are using a statistical model to exprapolate, which means that the estimates that we get here are nothing but estimates.
# - Data from the NFI is on 250x250m cells, and is generated through k-NN association with sample plot data; what this means is that there is a lot of averaging going on. As a consequence, if you compare the estimate of biomass in tons/ha obtained here with sample plot data, you will tend to see much higher maximum biomass measure from the sample plot data, since there a lot more extreme values than in the NFI data.
#
# The most important thing in the end is to make sure that the estimates of growth in ideal conditions we got here represent the differences between species quite well : whatever the values themselves, the ranking of species in terms of their growth capacity should be similar to their biological reality. It's hard to consider that when we mix it with the fact that there is an important intra-specific variability that can mix things up; but overall, if you see one species that is supposed to be not very competitive achieving a lot of biomass compared to another one that is know to be very competitive or to achieve a lot of biomass, you might want to take a look at your curves again, and maybe select a different spatial extent or dataset.
#
# Still, I consider this approach to be quite solid, especially after I contacted several researchers to get their opinion on it.

# %% [markdown]
# #### If you find a better approach for a different country than Canada, or a better approach otherall to get growth curves in ideal conditions

# %% [markdown]
# If you find a better approach, know that the growth curves selected here are simply exported into `.csv` files (in the folder `ReferencesAndData/Growth Curves Predictions/`) which are then re-used in the subsequent notebooks for the calibration of PnET-Succession.
#
# As such, you can implement you better approach by modifying this notebook, and export the curves your approach produces in a `.csv` file for each species (you can use the same names, e.g. Latin name_gam_predictions.csv). In that way, your approach will integrate nicely with the rest of the calibration, and you won't have to change much things.
#
# For the US, you might want to use this dataset instead of the NFI, which is quite similar : https://data.fs.usda.gov/geodata/rastergateway/bigmap/index.php.

# %% [markdown]
# ## Values needed to estimate certain parameters

# %% [markdown]
# ### Longevity and Max Longevity

# %% [markdown]
# What we will call here "Longevity" and "Max Longevity" are necessary to calibrate the senescence part of the growth curve for our species.
#
# The difference between the two is this, per the team of Brian Sturtevant who explained their methodology to me :
#
# - Longevity is the rule-of-thumb, expert opinion longevity for a given tree species. This is the age at which it's expected that a tree of a given species will die, in a give region. These are the number often reported in the litterature, and also used in the core species parameter file of LANDIS-II as its "Longevity" parameter for each tree species used.
# - Max Longevity is the real, empirical maximum age that a tree species can reach in the study area. It's often not reported and difficult to find. A good way to find it is to look at sample plot data and find the oldest trees ever found for a given species (which can be difficult to find as the "age" data is often not directly available in sample plots data).
#
# Brian Sturtevant and his team have used these two notions to calibrate the senescence part of the growth curves in ideal conditions as explained in [./6.Monoculture_ideal_conditions.py](./6.Monoculture_ideal_conditions.py).  This part from [this supplementary material of Reese et al. (2025)](https://cdnsciencepub.com/doi/suppl/10.1139/cjfr-2024-0085/suppl_file/cjfr-2024-0085suppla.docx) describes Brian's methodology of explains it all :
#
# > We used an unpublished review and analysis led by John Du Plissis at the University of Minnesota-Duluth to define both tree species longevity (the age at which a species age cohort can no longer persist) and the initiation of decline that is defined by the age-related photosynthesis reduction factor (PsnAgeRed) parameter in PnET Succession. In general, the maximum species longevity of Loehle (1988) corresponds with the tree species longevity parameter, while the typical species’ longevity from the same publication determines the initiation of decline, where PsnAgeRed is calibrated such that the fAGE (age reduction factor) begins to decline (~0.99) at the Typical Mortality age of the species.
#
#
# The data used by Brian's team for Typical Longevity and Max Longevity are cited as coming from https://sci-hub.st/https://cdnsciencepub.com/doi/10.1139/x88-032 in ReeseEtAl_CanJForRes_2024_supplA.docx ; it's an article that seem to compute them based on several characteristics of tree species.
#
# In the end, Brian's team is using a combination of data from [Loehle (1988)](https://cdnsciencepub.com/doi/10.1139/x88-032) and estimates found by John Du Plissis (yet unpublished). I'm going to use the data from [Loehle (1988)](https://cdnsciencepub.com/doi/10.1139/x88-032), which should be enough for our goals until the data from Du Plissis is published.
#
# [Loehle (1988)](https://cdnsciencepub.com/doi/10.1139/x88-032), defines "Typical" versus "Maximum" longevity in the following terms :
#
# > Typical longevity is the age of the older trees in an old-growth stand, whereas maximum longevity is the upper known maximum above which very few trees are found.
#
# We can find the value of typical longevity and maximum longevity from the Appendix 1 of [Loehle (1988)](https://cdnsciencepub.com/doi/10.1139/x88-032) (see end of the .pdf). Here are the values for our three species :

# %% [markdown]
# | Species | MINREP (years) | AVEREP (years) | TYPMORT (years) | MAXMORT (years) | Specific gravity | Growth rate | Shade tolerance | Volumetric heat (J·cm⁻³) | Decay resistance |
# | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- | :--- |
# | *Abies balsamea* | 15 | 30 | 125 | 150 | 0.34 | 4 | 5 | 6.42 | 1 |
# | *Picea mariana* | 10 | 18 | 150 | 250 | 0.43 | 2 | 4 | 7.91 | 1 |
# | *Acer rubrum* | 4 | | 80 | 150 | 0.49 | 4 | 2 | 9.93 | 1 |

# %% [markdown]
# ## Ranges of parameter values for the calibration

# %% [markdown]
# We're going to need bounds of parameter values during the calibration, so that we know when to stop increasing or decreasing a given parameter during a given calibration step.
#
# Problem is, it's hard to get different values of parameters for a given tree species, especially the rarer ones. Doubly so because almost every study that have used PnET-Succession so far (and which have published parameter values) don't specify the primary source of these parameters in detail.
#
# What I'm going to try to do here is to catalog different parameters values found in previous studies, but not per species; but rather for different caracteristics (i.e. deciduous versus coniferous, level of shade tolerance or drought tolerance, etc.). By doing this, we only have to label a given tree species properly, even if it is rare (i.e. finding out if the species is supposed to be shade tolerant or not, deciduous or coniferous, etc.), and we can then have parameter bounds for it.
#
# Note that some parameters (e.g. FolN) are affected both by the taxa of the species (coniferous versus deciduous) and their successional status (shade tolerant versus shade intolerant, or pioneer versus climax). However, I'll only put them in one category of variation - the one I expect where the variation will be greatest.
#
# ### Sources of values
#
# Sources :
#
# - [x] User guide of Pnet Succession, Table 2
# - [x] Ameray : https://www.frontiersin.org/articles/10.3389/ffgc.2023.1020305, parameters in https://github.com/Ameray/PhD-thesis/tree/main
# - [x] Mina's work in Quebec : https://esajournals.onlinelibrary.wiley.com/doi/10.1002/eap.2221 with parameters in https://github.com/mrcmina/REDEFINE-Mina_etal_EcolAppl/tree/1.0/Input_Data/PnET
# - 2014 De bruujin : Where are the parameters ? (Not done, parameters are in complex tables difficult to extract, and often don't have the same names as currently used parameters.
# - [x] Sturtevant : see files sent by Brian
# - [x] https://www.frontiersin.org/journals/ecology-and-evolution/articles/10.3389/fevo.2021.653393/full : where are the parameters ?

# %% [markdown]
# ### Parameters Correlated with Shade Tolerance (Successional Status)
#
# The distinction between the different levels of shade tolerance will be done based on TRY database traits or [Niinemets and Valladares (2006)](https://doi.org/10.1890/0012-9615(2006)076[0521:TTSDAW]2.0.CO;2), or by a quick research. The mentions "shade tolerant", "somewhat tolerant", etc. corredponds to score 1-5 of shade tolerance from [Niinemets and Valladares (2006)](https://doi.org/10.1890/0012-9615(2006)076[0521:TTSDAW]2.0.CO;2).
#
# | Parameter | Justification for inclusion here | Shade intolerant | Somewhat shade intolerant | Intermediate shade tolerant | Somewhat shade tolerant | Shade tolerant |
# |:-:|:-|:-:|:-:|:-:|:-:|:-:|
# | HalfSat | The primary parameter for shade tolerance. Pioneers have high values (e.g., 275), meaning they require more light to be productive, while climax species have low values (e.g., 150) to remain efficient in the shade. | 275 [^1], 250 [^1], 213 [^6], 250 [^6], 260 [^11], 270 [^11], 250 [^11], 280 [^11], 282.5 [^16], 266 [^16], 263 [^16], 268 [^16], 275[^16] | 244 [^2], 212.5 [^2], 228 [^2], 210 [^7], 180 [^7], 230 [^7], 270 [^12], 264.5 [^17], 245 [^17], 266.5 [^17], 227 [^17], 243 [^19], 258 [^19], 247 [^19] | 181 [^3], 197 [^3], 244 [^3], 197 [^3], 212.5 [^3], 137 [^8], 175 [^8], 200 [^8], 150 [^8], 270 [^13], 208 [^20], 214 [^20], 221 [^20], 209 [^20], 199 [^20], 220 [^20], 182 [^20], 206 [^20], 207 [^20] | 197 [^4], 181 [^4], 137 [^9], 210 [^14], 200 [^14], 220 [^14], 182 [^21] | 134 [^5], 149 [^5], 148 [^5], 133 [^5], 100 [^10], 180 [^15], 150 [^22], 158 |
# | MaxFracFol | With FracFolShape, controls the "dynamic" foliage response in high-light conditions. They are set high for pioneers to allow rapid early biomass accumulation in open sites, whereas climax species have lower initial growth targets. | 0.065 [^18], 0.042 [^18], 0.135 [^18], 0.075 [^18], 0.048 [^18] | 0.055 [^19], 0.031 [^19], 0.048 [^19] | 0.052 [^20], 0.031 [^20], 0.036 [^20], 0.025 [^20], 0.024 [^20], 0.027 [^20], 0.115 [^20], 0.122 [^20], 0.017 [^20] | 0.027 [^21], 0.059 [^21], 0.138 [^21] | 0.112 [^22], 0.015 [^22] |
# | FracFolShape | With MaxFracFol, controls the "dynamic" foliage response in high-light conditions. They are set high for pioneers to allow rapid early biomass accumulation in open sites, whereas climax species have lower initial growth targets. | 6 [^18] | 6 [^19] | 6 [^20] | 6 [^21] | 6 [^22] |
./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf), Table 2, somewhat waterlogging tolerant species : Fraxinus nigra
# [^57]: [Ameray et al. 2023](https://www.frontiersin.org/articles/10.3389/ffgc.2023.1020305), [Github repo](https://github.com/Ameray/PhD-thesis/tree/main/chapter2/MU1), waterlogging intolerant species : Picea glauca, Pinus banksiana, Betula papyrifera
# [^58]: [Ameray et al. 2023](https://www.frontiersin.org/articles/10.3389/ffgc.2023.1020305), [Github repo](https://github.com/Ameray/PhD-thesis/tree/main/chapter2/MU1), somewhat waterlogging intolerant species : Betula alleghaniensis, Picea mariana, Abies balsamea, Populus tremuloides
# [^59]: [Ameray et al. 2023](https://www.frontiersin.org/articles/10.3389/ffgc.2023.1020305), [Github repo](https://github.com/Ameray/PhD-thesis/tree/main/chapter2/MU1), intermediate waterlogging tolerant species : Larix laricina
# [^60]: Parameters gathered and calibrated by Brian Sturtevant's team at the USDA, yet unpublished, waterlogging intolerant species : Tilia americana, Pinus banksiana, Betula papyrifera, Quercus rubra, Pinus resinosa, Acer saccharum, Thuja occidentalis, Pinus strobus, Picea glauca
# [^61]: Parameters gathered and calibrated by Brian Sturtevant's team at the USDA, yet unpublished, somewhat waterlogging intolerant species : Ulmus americana, Abies balsamea, Populus grandidentata, Picea mariana, Quercus macrocarpa, Quercus imbricaria, Populus tremuloides, Betula alleghaniensis
# [^62]: Parameters gathered and calibrated by Brian Sturtevant's team at the USDA, yet unpublished, intermediate waterlogging tolerant species : Populus balsamifera, Fraxinus pennsylvanica, Acer rubrum, Larix laricina
# [^63]: Parameters gathered and calibrated by Brian Sturtevant's team at the USDA, yet unpublished, somewhat waterlogging tolerant species : Fraxinus nigra

# %% [markdown]
# ### Parameters that we will calibrate for which we don't choose bounds :
#
# - MaxPest : Goes from 0 to 1, depends on the timestep.
# - EastRad : Goes from 0 to 1, already quite bounded.
# - InvertPest : True of false
# - MaxCanopyLayers : Already have pretty narrow bounds and recommanded values
# - MaxLAI : Optional, and seem to have effects on growth that I don't fully understand according to the user guide. The user guide recommands using other means to control the beginning of the growth. I'll let this one go, and simply use the "Target LAI" values of Gustafson in his calibration tips instead.

# %% [markdown]
# ### Computing the bounds

# %%
## COMPUTING THE BOUNDS
# Now that have all of the values together, we are going to compute the bounds for each parameter.
# For that, we use some functions that will extend the bounds to deal with uncertainty when we have
# few values, and functions that will compute bounds with a linear model 

# WARNING : If you add new cells before this one or if you change the name of the notebook, you'll have
# to re-specify the new cell number and the the new notebook name, or the functions will not work.

from functionsForCalibration import *

# Reading the table with shade tolerance variation
shade_tolerance_parameters = parse_parameters_bounds_table("./4.Getting_the_empirical_data.ipynb", 31)
# Computing the bounds from it
bounds_shadeTolerance_Parameters = compute_all_bounds(shade_tolerance_parameters, expansion_factor=0.5, trend_min_n = 4, verbose=False)

# Reading the table for drought tolerance variantion
drought_tolerance_parameters = parse_parameters_bounds_table("./4.Getting_the_empirical_data.ipynb", 33)
# Computing the bounds from it
bounds_droughtTolerance_Parameters = compute_all_bounds(drought_tolerance_parameters, expansion_factor=0.5, trend_min_n = 4, verbose=False)

# Reading the table for waterlogging tolerance variantion
waterlogging_tolerance_parameters = parse_parameters_bounds_table("./4.Getting_the_empirical_data.ipynb", 34)
# Computing the bounds from it
bounds_waterloggingTolerance_Parameters = compute_all_bounds(waterlogging_tolerance_parameters, expansion_factor=0.5, trend_min_n = 4, verbose=False)

# Reading the table for coniferous versus deciduous/angiosperms
coniferousVersusAngiosperms_parameters = parse_parameters_bounds_table("./4.Getting_the_empirical_data.ipynb", 32)
# Computing the bounds from it
bounds_coniferousVersusAngiosperms_Parameters = compute_all_bounds(coniferousVersusAngiosperms_parameters, expansion_factor=0.5, trend_min_n = 4, verbose=False)

# %% [markdown]
# ### Creating the final dictionnary that will contain the bounds of variation of parameters for each species
#
# To make this final dictionnary, we're going to input the shade tolerance, drought tolerance and waterlogging tolerance of each of our tree species in a dictionnary, with exactly the same mentions as the markdown tables above (e.g. "Shade intolerant", "Somewhat shade intolerant", etc.).
#
# Normally, this is quite easy to do using the values from [Niinemets and Valladares (2006)](https://doi.org/10.1890/0012-9615(2006)076[0521:TTSDAW]2.0.CO;2).

# %%
from functionsForCalibration import *

## Defining the traits for each of our species
# THIS IS WHAT YOU HAVE TO FILL WITH YOUR SPECIES

dictOfShadeTolerance = { 
                        "ABIE.BAL":"Shade tolerant",
                        "ACER.RUB":"Intermediate shade tolerant",
                        "PICE.MAR":"Somewhat shade tolerant"
}
dictOfDroughtTolerance = { 
                        "ABIE.BAL":"Drought intolerant",
                        "ACER.RUB":"Somewhat drought intolerant",
                        "PICE.MAR":"Somewhat drought intolerant"
}
dictOfWaterloggingTolerance = { 
                        "ABIE.BAL":"Somewhat waterlogging intolerant",
                        "ACER.RUB":"Intermediate waterlogging tolerant",
                        "PICE.MAR":"Somewhat waterlogging intolerant"
}
dictOfConiferousVersusAngiosperm = { 
                        "ABIE.BAL":"Coniferous",
                        "ACER.RUB":"Deciduous/Angiosperm",
                        "PICE.MAR":"Coniferous"
}


finalDictionaryWithBounds = {}
for species in dictOfShadeTolerance.keys():
    finalDictionaryWithBounds[species] = dict()
    for parameter in bounds_shadeTolerance_Parameters:
        finalDictionaryWithBounds[species][parameter] = dict()
        finalDictionaryWithBounds[species][parameter]["lower"] = bounds_shadeTolerance_Parameters[parameter][dictOfShadeTolerance[species]]["lower"]
        finalDictionaryWithBounds[species][parameter]["upper"] = bounds_shadeTolerance_Parameters[parameter][dictOfShadeTolerance[species]]["upper"]
    for parameter in bounds_droughtTolerance_Parameters:
        finalDictionaryWithBounds[species][parameter] = dict()
        finalDictionaryWithBounds[species][parameter]["lower"] = bounds_droughtTolerance_Parameters[parameter][dictOfDroughtTolerance[species]]["lower"]
        finalDictionaryWithBounds[species][parameter]["upper"] = bounds_droughtTolerance_Parameters[parameter][dictOfDroughtTolerance[species]]["upper"]
    for parameter in bounds_waterloggingTolerance_Parameters:
        finalDictionaryWithBounds[species][parameter] = dict()
        finalDictionaryWithBounds[species][parameter]["lower"] = bounds_waterloggingTolerance_Parameters[parameter][dictOfWaterloggingTolerance[species]]["lower"]
        finalDictionaryWithBounds[species][parameter]["upper"] = bounds_waterloggingTolerance_Parameters[parameter][dictOfWaterloggingTolerance[species]]["upper"]
    for parameter in bounds_coniferousVersusAngiosperms_Parameters:
        finalDictionaryWithBounds[species][parameter] = dict()
        finalDictionaryWithBounds[species][parameter]["lower"] = bounds_coniferousVersusAngiosperms_Parameters[parameter][dictOfConiferousVersusAngiosperm[species]]["lower"]
        finalDictionaryWithBounds[species][parameter]["upper"] = bounds_coniferousVersusAngiosperms_Parameters[parameter][dictOfConiferousVersusAngiosperm[species]]["upper"]

print(finalDictionaryWithBounds)

# We save the dictionnary into a JSON file
import json
with open('./SpeciesParametersSets/SpeciesParameterBounds.json', 'w') as f:
    json.dump(finalDictionaryWithBounds, f)
# Out:
# {'ABIE.BAL': {'HalfSat': {'lower': 77.632591650257, 'upper': 202.36740834974302}, 'MaxFracFol': {'lower': -0.012890462214302345, 'upper': 0.0664460177698579}, 'FracFolShape': {'lower': 6.0, 'upper': 6.0}, 'FracBelowG': {'lower': 0.28057493028755537, 'upper': 0.41942506971244464}, 'PsnAgeRed': {'lower': 1.7805405234735865, 'upper': 3.9572372543041947}, 'TOWood': {'lower': 0.004790309316655255, 'upper': 0.035209690683344744}, 'TORoot': {'lower': 0.018133582871652024, 'upper': 0.038789494051424914}, 'H3': {'lower': 91.49807224356104, 'upper': 166.50192775643896}, 'H4': {'lower': 128.1424095435094, 'upper': 171.8575904564906}, 'H1': {'lower': -5.55, 'upper': 0.32999999999999885}, 'H2': {'lower': 0.8600569830635258, 'upper': 4.5399430169364745}, 'FracFol': {'lower': 0.04, 'upper': 0.11}, 'SLWmax': {'lower': 93.23, 'upper': 250.0}, 'FrActWd': {'lower': 1.9600000000000002e-05, 'upper': 6.199999999999999e-05}, 'FolN': {'lower': 0.528, 'upper': 2.189999999999999}, 'TOFol': {'lower': 0.19, 'up
# ...

# %% [markdown]
# ## Preparing data for competition outcomes

# %% [markdown]
# ### Drought and waterlogging tolerance

# %% [markdown]
# Used to calibrate the reaction of the species to conditions of drought or waterlogging (see [7. Calibrating soil and water.ipynb](./7. Calibrating soil and water.ipynb)).
#
# These traits are taken from the [TRY database](https://www.try-db.org/TryWeb/Home.php). See code above that generate a Python dictionnary with estimates of drought and waterlogging tolerance on a scale from 1 to 5.

# %%
from functionsForCalibration import *

dictionnaryOfTraits = extract_try_traits("./ReferencesAndData/Functional Traits/TRY_Database_AccessedDecember2025_Tolerances.txt")
print(dictionnaryOfTraits)

averageTraitTol = average_tolerance_traits(dictionnaryOfTraits)
print(averageTraitTol)

# We save the averaged traits to a JSON dictionary
with open("./ReferencesAndData/Functional Traits/SpeciesTolerances.json", 'w') as file:
    json.dump(averageTraitTol, file, indent=4)
# Out:
# {'Abies balsamea': {'Species tolerance to shade': ['5.01', 'Tolerant', '5.01', '5'], 'Species tolerance to drought': ['1', 'Low', '1', '1'], 'Species tolerance to waterlogging': ['2', 'None', '2', '2'], 'Species tolerance to fire': ['No', 'Low', 'No', 'low']}, 'Acer rubrum': {'Species tolerance to shade': ['3.44', 'late-successional', 'late-successional', 'Tolerant', '3.44'], 'Species tolerance to drought': ['1.84', 'Low', '1.84'], 'Species tolerance to waterlogging': ['3.08', 'Medium', '3.08'], 'Species tolerance to fire': ['No', 'Low', 'low']}, 'Picea mariana': {'Species tolerance to shade': ['4.08', 'Tolerant', 'Intolerant', '4.08', '4.08'], 'Species tolerance to drought': ['2', 'Low', 'Medium', '2', '2'], 'Species tolerance to waterlogging': ['2', 'Low', 'None', '2', '2'], 'Species tolerance to fire': ['0', 'No', 'None', 'No', 'Low', 'Crown fire', 'low', 'low', 'no', 'none']}}
# Ignored values (unrecognized):
#   - Crown fire
# ...

# %% [markdown]
# ### Temperature tolerance/species optimal temperature

# %% [markdown]
# To create expected outcomes of competitions between species in conditions of increasing temperature, we need to have some idea of the either the tolerance of each tree species to higher temperature, or of the temperature they prefer to grow well.
#
# Unfortunately, I wasn't able to find any dataset regarding the temperature tolerance of best growth temperatures of tree species in Canada. While the TRY database have traits linked to temperature tolerance or preference, there seem to be relatively few measurements for Canadian tree species.
#
# I've decided to go with an alternative route, and to compute estimates of the favorite growth temperature of species based on a simple assumption : where the tree species is most present/abundant in Canada, then the temperature is best for it. This is an imperfect assumption of course, as soils, disturbances and competition with other species also affect its presence; but I'll consider it enough to produce reliable estimates that will give us a broad idea of the temperatures the species prefer.
#
# Temperatures and precipitations are, according to the litterature, two of the most important factors explaining the distribution of tree species on earth. However, the effect of temperature on trees can appear in different ways, sometimes indirect; for example, by killing out insects or diseases that will attack the tree in other regions. As such, it's not because a tree species is most abundant in a place with a given temperature that this means that this temperature is optimal for its growth : it might be that other effects of the temperatures (and also of precipitations) are at play to help the species grow in this place.
#
# Here, we want to get a temperature for each tree species that reflects their relative "sweet spot" of growth (where their temperature is optimal for growth), which will help us predict the outcome of competition between our tree species in condtions where temperatures (and shade) are the only factors of competition. Ideally, we would get these through expeximentation, where we can put tree saplings in controlled conditions and with different temperatures in order to see how they respond to it. This would allow us to isolate the direct effect of temperature on tree growth, independant of other factors (i.e. disturbances, solar radiation, precipitations, etc.).
#
# Unfortunatly, we do not have such experimentation data for tree species in Canada. But we do know that the direct effect of temperature on tree growth is one of the forces shapping the repartition of tree species in Canada. As such, I make the assumption that by looking at the average summer temperature accross Canada that we then average by ponderating it by the distribution of the biomass of the species accross Canada, we will get a value that is pretty close the optimal growth temperature of the species.
#
# :::{tip}
# To read more about the limitations of this approach, and especially the lack of correlation between the localisation of a species and its optimal temperature, see [here](https://academic.oup.com/treephys/article-abstract/30/6/669/1614202).
#
# Also, you can read about the fact that while temperature as an effect on tree growth, in nature, this interact very closely with water availability, and that the notion of "optimal temperature" thus tends to change with the availability of water; see [here](https://pubmed.ncbi.nlm.nih.gov/31883292/).
#
# So again, this approach has a lot of limitation; but I will still use it to try and catch any strange behavior from the model when species are competiting with each other in changing temperature conditions.
# :::

# %%
# Beforehand : importing packages + setting up the paths
# we are going to use
import numpy as np
import xarray as xr
import rasterio
import requests
from pathlib import Path
from tqdm import tqdm
import os
from pyproj import CRS
from rasterio.warp import reproject, Resampling
import json

# URL for the OpenDAP access to the climate data
# we will use to compute average summer temperatures
# URL taken from the THREDDS server of Ouranos
# See https://zenodo.org/records/17465777 for the URLS
# We choose the agregatted datasets (all years and variables in one dataset)
# at a monthly resolution for simulation with the MPI-ESM1-2-LR as the driver model of CRCM5.
# MPI-ESM1-2-LR has been recommanded as the best model for a calibration on historical data
# by Dominique Paquin, main author associated with these datasets.
climateDataURL = "https://pavics.ouranos.ca/twitcher/ows/proxy/thredds/dodsC/datasets/simulations/RCM-CMIP6/CORDEX/NAM-12/mon/NAM-12_MPI-ESM1-2-LR_historical_r1i1p1f1_OURANOS_CRCM5_v1-r1_mon_195001-201412.ncml"

# Path where we will save the raster with our summer temperature averaged
# This raster will have a pretty low resolution (0.11 arc degrees) and will cover Canada only,
# so it is very light.
exportPathSumerTempRaster = './ReferencesAndData/Climate Data/climate_summer_temp_latlon_Canada.tif'

# Path to the NFI raster for aboveground biomass
biomassNFIRasterPath = "./ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Structure_Biomass_TotalLiveAboveGround_v1.tif"

# Path to the NFI rasters for the species abundance; SPECIES_NAME has to be replaced by the name of the species.
speciesNFIRasterPath = "./ReferencesAndData/NFI_Data/NFI_MODIS250m_2011_kNN_Species_SPECIES_NAME_v1.tif"

# List of species we are going to get the temperature for; 
# derived from the parameters loaded in 3.Initial_Species_Parameters.ipynb
with open("./SpeciesParametersSets/Initial/initialPnETSpeciesParameters.json", 'r') as source:
    speciesList = list(json.load(source)["PnETSpeciesParameters"].keys())
print("Species to be investigated : " + str(speciesList))

# We load the JSON dictionary in which we will save the average temperatures
# It's the dictionnary in which we saved TRY traits before
with open("./ReferencesAndData/Functional Traits/SpeciesTolerances.json", 'r') as file:
    speciesToleranceTraitsDict = json.load(file) 

# We load the JSON dictionary containing the equivalence between species full names and species code,
# which is needed at some point
with open("./ReferencesAndData/NFI_Data/NFI_SpeciesNameEquivalence.json", 'r') as file:
    speciesCodeDict = json.load(file) 
    # We reverse it because we will need the opposite
    speciesCodeDict_Inverted = {v: k for k, v in speciesCodeDict.items()}
# Out:
# Species to be investigated : ['ABIE.BAL', 'ACER.RUB', 'PICE.MAR']

# %%
print("\nStep 1: Loading Ouranos climate data with latitude subset...")
print("  Opening OPeNDAP dataset...")

ds = xr.open_dataset(climateDataURL)

# Get coordinate names
# Allows us to adapt to more formats of 
lon_name = 'lon' if 'lon' in ds.coords else 'longitude'
lat_name = 'lat' if 'lat' in ds.coords else 'latitude'

# Subset to latitudes >= 40°N【0】
# I do this because subsetting with a polygon that corresponds to Canada
# or to the extent of the NFI raster has proven to be quite the headache.
# This is simpler and it works very well.
print("  Subsetting to latitudes >= 40°N to reduce the data downloaded")
if ds[lat_name].ndim == 1:
    # 1D coordinates - simple selection
    ds_subset = ds.where(ds[lat_name] >= 40, drop=True)
else:
    # 2D coordinates - need to check any latitude value in row
    lat_mask = (ds[lat_name] >= 40).any(dim=ds[lat_name].dims[1])
    ds_subset = ds.isel({ds[lat_name].dims[0]: lat_mask})

print(f"  Subset dataset shape: {dict(ds_subset.dims)}")

# Filter for 1962-2011 and summer months
print("  Filtering temporal range (1962-2011) and summer months...")
ds_filtered = ds_subset.sel(time=slice('1962-01-01', '2011-12-31'))
summer_months = ds_filtered['time.month'].isin([6, 7, 8])
tas_summer = ds_filtered['tas'].isel(time=summer_months)

# Calculate mean summer temperature (convert K to °C)
print("  Computing mean summer temperature...")
mean_summer_temp = tas_summer.mean(dim='time') - 273.15

# Load into memory
print("  Loading climate data into memory...")
mean_summer_temp = mean_summer_temp.load()

print(f"  Climate data shape: {mean_summer_temp.shape}")
print(f"  Temperature range: {float(mean_summer_temp.min()):.2f}°C - {float(mean_summer_temp.max()):.2f}°C")
# Out:
# Step 1: Loading Ouranos climate data with latitude subset...
#   Opening OPeNDAP dataset...
#   Subsetting to latitudes >= 40°N to reduce the data downloaded
# /tmp/ipykernel_2410/933262165.py:24: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   print(f"  Subset dataset shape: {dict(ds_subset.dims)}")
#   Subset dataset shape: {'rlat': 390, 'rlon': 655, 'bounds': 4, 'time': 780, 'bnds': 2}
#   Filtering temporal range (1962-2011) and summer months...
#   Computing mean summer temperature...
#   Loading climate data into memory...
#   Climate data shape: (390, 655)
#   Temperature range: -13.79°C - 25.34°C

# %%
print("\nStep 2: Creating a raster from the average summer temperatures from the climate dataset...")

# Extract grid mapping attributes from the crs coordinate
# of the original dataset loaded with OpenDAP from Ouranos's servers
crs_var = ds['crs'].attrs
# print(crs_var)
# Create the rotated pole CRS
rotated_crs = CRS.from_cf(crs_var)

mean_summer_temp = mean_summer_temp.rio.set_spatial_dims(x_dim="rlon", y_dim="rlat", inplace=False)
mean_summer_temp = mean_summer_temp.rio.write_crs(rotated_crs, inplace=False)

# Reproject and save
mean_summer_temp_reprojected = mean_summer_temp.rio.reproject("epsg:4326")
mean_summer_temp_reprojected.rio.to_raster(exportPathSumerTempRaster)

print("The raster of average summer temperatures has been exported to " + str(exportPathSumerTempRaster))
# Out:
# Step 2: Creating a raster from the average summer temperatures from the climate dataset...
# The raster of average summer temperatures has been exported to ./ReferencesAndData/Climate Data/climate_summer_temp_latlon_Canada.tif

# %%
print("\nStep 3: Resampling climate raster to NFI resolution...")

# Gathering metadata about dimension and resolution
# of the NFI rasters to which we want to resample
# climate data
with rasterio.open(biomassNFIRasterPath) as src:
    biomass = src.read(1).astype(np.float32)
    biomass_meta = src.meta.copy()
    biomass_transform = src.transform
    biomass_crs = src.crs

# Open climate raster
with rasterio.open(exportPathSumerTempRaster) as src_climate:
    # Use NFI raster dimensions and transform
    nfi_temp = np.zeros((biomass.shape[0], biomass.shape[1]), dtype=np.float32)

    print(f"  Reprojecting from {src_climate.crs} to {biomass_crs}...")
    print(f"  Target shape: {nfi_temp.shape}")

    # Reproject climate data to NFI grid
    reproject(
        source=rasterio.band(src_climate, 1),
        destination=nfi_temp,
        src_transform=src_climate.transform,
        src_crs=src_climate.crs,
        dst_transform=biomass_transform,
        dst_crs=biomass_crs,
        resampling=Resampling.bilinear
    )

print(f"  ✓ Reprojection complete")
print(f"  Resampled temperature range: {np.nanmin(nfi_temp):.2f}°C - {np.nanmax(nfi_temp):.2f}°C")
print(f"  Unique temperature values in resampled data: {len(np.unique(nfi_temp[~np.isnan(nfi_temp)]))}")

# Save resampled temperature raster
# temp_raster_path = './ReferencesAndData/Climate Data/summer_temperature_1962_2011_250m.tif'
# print(f"  Saving resampled temperature raster: {temp_raster_path.name}")
# with rasterio.open(temp_raster_path, 'w', **biomass_meta) as dst:
#     dst.write(nfi_temp, 1)
# print(f"  ✓ Resampled temperature raster saved")
# Out:
# Step 3: Resampling climate raster to NFI resolution...
#   Reprojecting from EPSG:4326 to PROJCS["NAD_1983_Canada_Lambert",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101004,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4269"]],PROJECTION["Lambert_Conformal_Conic_2SP"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-95],PARAMETER["standard_parallel_1",49],PARAMETER["standard_parallel_2",77],PARAMETER["false_easting",0],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]...
#   Target shape: (19200, 22800)
#   ✓ Reprojection complete
#   Resampled temperature range: -13.77°C - 25.14°C
#   Unique temperature values in resampled data: 71905829

# %%
# TRY TO MAKE THIS SECTION SMALLER
# And to re-use functions to download files that are already ready

print("\nStep 4: For each species, loading species abundance raster and computing biomass-ponderated average summer temperature")

print("Loading NFI aboveground biomass raster")
with rasterio.open(biomassNFIRasterPath) as src:
    # Handle nodata values for the NFI biomass raster (-3.4028235e+38)
    # These nodata values, if not indicated as nan, will mess up our computation later
    biomass_nodata = -3.4028235e+38
    print(f"  Biomass nodata value: {biomass_nodata}")
    biomass[biomass == biomass_nodata] = np.nan
    biomass[biomass < 0] = np.nan  # Additional safety for any negative values
    print(f"  Valid biomass cells: {np.sum(~np.isnan(biomass)):,}")


print("Loading NFI species raster and computing average temperature")
for species in speciesList:
    # The name of the species in the name of their respective NFI rasters is a bit different
    # than the NFI nomenclature (paradoxically) that we use in our parameter files.
    # We have to change it to get the right link.
    speciesNameForRasterPath = species.split(".")[0].capitalize() + "_" + species.split(".")[1].capitalize()
    speciesNFIRasterPath_Right = speciesNFIRasterPath.replace("SPECIES_NAME", speciesNameForRasterPath)

    # Loading the species abundance raster and dealing with its nodata values.
    with rasterio.open(speciesNFIRasterPath_Right) as src:
        species_pct = src.read(1).astype(np.float32)
        # Handle nodata values for the species raster (-9999)
        species_nodata = -9999
        # print(f"  Species nodata value: {species_nodata}")
        species_pct[species_pct == species_nodata] = np.nan
        species_pct[species_pct < 0] = np.nan  # Additional safety
        # print(f"  Valid species cells: {np.sum(~np.isnan(species_pct)):,}")

    # Calculate species biomass by multiply its abundance raster with the aboveground biomass raster
    print("  Computing species biomass...")
    species_biomass = (biomass * species_pct / 100.0).astype(np.float32)
    valid_biomass = species_biomass[~np.isnan(species_biomass) & (species_biomass > 0)]
    # if len(valid_biomass) > 0:
    #     print(f"  Species biomass range: {valid_biomass.min():.2f} - {valid_biomass.max():.2f} Mg")
    # else:
    #     print(f"  WARNING: No valid species biomass found!")

    # Mask invalid data (nan of infinite)
    valid_mask = (species_biomass > 0) & (~np.isnan(nfi_temp)) & (~np.isnan(species_biomass)) & (~np.isinf(species_biomass))
    print(f"  Valid cells for calculation: {valid_mask.sum():,}")
    
    if valid_mask.sum() == 0:
        print("\n  ERROR: No valid cells found for calculation!")
    else:
        # Vectorized weighted average
        weighted_sum = np.sum(nfi_temp[valid_mask] * species_biomass[valid_mask])
        total_biomass = np.sum(species_biomass[valid_mask])
        optimal_temp = weighted_sum / total_biomass
    
        print(f"\n{'='*60}")
        print(f"RESULTS FOR {species}")
        print(f"{'='*60}")
        print(f"Total species biomass: {total_biomass:,.2f} Mg")
        print(f"Number of cells with species: {valid_mask.sum():,}")
        print(f"Optimal summer temperature: {optimal_temp:.2f}°C")
        print(f"{'='*60}")

        # We save the temperature into the dictionnary
        # We have to detected the right species
        speciesToleranceTraitsDict[speciesCodeDict_Inverted[species]]["Estimated optimal summer temperature"] = optimal_temp

        # We delete the unused arrays
        del species_pct

# We save and display the dictionnary
print(speciesToleranceTraitsDict)
with open("./ReferencesAndData/Functional Traits/SpeciesTolerances.json", 'w') as file:
    json.dump(speciesToleranceTraitsDict, file, indent=4)
# Out:
# Step 4: For each species, loading species abundance raster and computing biomass-ponderated average summer temperature
# Loading NFI aboveground biomass raster
#   Biomass nodata value: -3.4028235e+38
#   Valid biomass cells: 154,036,356
# Loading NFI species raster and computing average temperature
#   Species nodata value: -9999
#   Valid species cells: 154,036,356
#   Computing species biomass...
#   Species biomass range: 0.00 - 116.90 Mg
#   Valid cells for calculation: 32,674,827
#
# ...
# RESULTS FOR ABIE.BAL
# ...
# Total species biomass: 221,214,672.00 Mg
# Number of cells with species: 32,674,827
# Optimal summer temperature: 14.39°C
# ...
#   Species nodata value: -9999
#   Valid species cells: 154,036,356
#   Computing species biomass...
#   Species biomass range: 0.00 - 58.22 Mg
#   Valid cells for calculation: 8,337,062
#
# ...
# RESULTS FOR ACER.RUB
# ...
# Total species biomass: 43,259,704.00 Mg
# Number of cells with species: 8,337,062
# Optimal summer temperature: 16.38°C
# ...

# %% [markdown]
# ### Computing expected competition outcomes between species

# %% [markdown]
# After the first calibration step (where we simulate an ideal situation for each tree species with no competition, good soil and enough precipitations for water, etc.), we will do several more step where we will check if the model produces "realistic" competition outcomes of species against species in several conditions :
#
# - Competition for shade (two species together with a good water input through soil and precipitation)
# - Drought (two species together but with a lack of water)
# - Waterlogging (two species together but too much water)
# - Temperature (two species together with increased temperatures)
#
# This is inspired by this text from the [calibration tips of Eric Gustafson](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) :
#
# > It is prudent to test the competitive behavior of pairs of species to ensure that the behavior is appropriate. I recommend that you conduct some tests of two and/or three species combinations using your calibration setup to ensure that species compete as you would expect. Extremely poor competitive ability usually results only when a cohort is inappropriately overtopped by another and becomes lightstarved. (...) It is highly recommended that you verify your calibrations by simulating several similar species together to ensure that they in fact compete as expected. If not, often a slight tweak of one parameter can bring them in line with expectations.
#
# Ideally, we will test every species against another, and see which one "wins" by having the most biomass in the pixel after a long time (100 years), and compare this against "expected outcomes". Expected outcomes are predictions we will make in advance based on what we know of the biology of each tree species. For example, if we put a shade tolerant species with a shade intolerant species in competition in otherwise ideal conditions of water and temperature, we expect the shade tolerant species to "win" on the long term. If the model cannot produce the expected outcomes, that might mean that we haven't represented the differences between species in the right way (e.g., their relative difference in shade tolerance is not implemented well enough in our parameters). But getting these inter-species different is crucial according to [Eric Gustafson](./ReferencesAndData/Documentation/Gustafson2024PnETUserGuide.pdf) so that the model can properly represent the competition outcomes between them.
#
# But it's not that simple. Here, the challenge comes in defining the expected outcomes (how do we know which species is going to win ?) and what "winning" means.
#
# - Defining a win is difficult because of the variability that comes with it. E.g., a shade tolerant species versus a shade intolerant one might reach more biomass than the other after 100 years; but maybe not if the cohorts starts at very different age, or with very different biomass. For example, the competiton could start with a very large and old shade intolerant cohort, which will take the shade tolerant species a long time to overcome.
# - Defining the expected outcomes (who wins) is also difficult because we have no solid empirical data on the competition between species; or at least, not enough empirical data to quantity how easy or how frequent it will be to win for a species against another. How do we know if *Acer rubrum* will tend to "win" against *Abies balsamea* in a competition for light one 100 years of simulation ? It's doubly difficult because empirical data comes from a place where many competitions and factor affect tree growth at once (shade, water, temperature, etc.), along with disturbances (which we're not including here).
#
# As such, the best we can do here is to use arbitrarely-defined expected outcomes (although based on the real and empirical/know difference in shade tolerance, drought tolerance, etc...of our species), and use arbitrarely-defined definitions of a "win" and of a threshold above which we consider that there is too much difference between the expected outcome of the actual ouctomes of the competition from the simulations.
#
# To define the expected outcomes, I propose to use the tolerance traits that can be found in the [TRY database](https://www.try-db.org/TryWeb/Home.php) : Shade tolerance, drought tolerance, waterlogging tolerance, as well as the optimal temperature we calculated in a previous section. These traits are often used in other LANDIS-II studies (see supp. material from [Reese et al. 2024](https://cdnsciencepub.com/doi/10.1139/cjfr-2024-0085)) to calibrate PnET-Succession of produce expected outcomes.
#
# Here is the arbitrary methodology that I propose to use :
#
# - We define a "win" when one species has achieved more biomass than the other after 100 years of simulation.
# - To define the intensity or the variation in "winning" for one species competing against another, we will make many simulations where we start with cohorts of different ages for the two species. We will compute the amount of cells in which, after 100 years of simulation, the "challenger" species has more biomass than the "opponent" species. This amount will correspond to the intensity of "wins". For example, if 60% of cells have more biomass for the challenger species after 100 years of simulation, then we will say that it has a win rate of 60%.
# - To define the expected outcomes, we will do a simple computation based on the tolerance traits, but always account for the competition for shade (which is still there despite the inclusion of drought, waterlogging or changing temperatures)
#     - For shade, the expected win will be derived linearly from the following rules :
#         - If the challenger species has a tolerance of 5 (very tolerant) and the opponent has a tolerance of 1 (very intolerant), then we expect a 100% winning frequency for the challenger.
#         - If the oppososite happens (1 for the challenger, 5 for the opponent), we expect a 0% winning frequency.
#         - If the challenger and the oponnent have the same shade tolerance, we expect a 50% winning frequency.
#         - For any other combination of shade tolerance between challenger and opponent, we derive the winning frequency linearly from the previous rules (`prob_win = 0.5 + 0.125 * diff`)
#     - For drought and waterlogging, the rules are as follow :
#         - Simulations for drought will be done with an excessively drained soil that doesn't retain water much (e.g. coarse sand), as per the supp. material A from [Reese et al. 2024](https://cdnsciencepub.com/doi/10.1139/cjfr-2024-0085)
#         - Simulatons for waterlogging will be done with a soil that retains water a lot (e.g.. mucky peat), as per supp. material A from [Reese et al. 2024](https://cdnsciencepub.com/doi/10.1139/cjfr-2024-0085)
#         - We first compute the frequency of winning with the same rule à with the shade tolerance (see above), but with the drought tolerance or waterlogging tolerance used in the calculation instead.
#         - Then, we also compute the frequency of winning the shade competition (based on the shade tolerance) with the same rule as before.
#         - We then compute the final expected frequency of winning the competition by doing a ponderated average of the expected frequency of winning the shade competition, and the expected frequency of winning the drought or waterlogging competition. In that way, we still account for the shade competition happenning.
#     - For temperatures, the rules are as follow :
#         - If the challenger species has an optimal temperature (as calculated in a previous section) that is 5 degrees celcius or more closer to the average summer temperature that will be use in the competition simulation when compared to the opponent species, then it has 100% change winning. For example : if the average summer temperature in the simulation is 12 degrees celcius, and the optimal temperature of the challenge is 11 degrees while the one of the opponent is 6 degrees celcius, then the challenger species has an optimal temperature 5 degrees closers to the average summer temperature in the simulation, and is therefore predicted to have 100% change winning.
#         - If the opposite happens, then we expect a 0% winning frequency for the challenger.
#         - We then compute the final expected frequency of winning the competition by doing a ponderated average of the expected frequency of winning the temperature competition, and the expected frequency of winning the drought or waterlogging competition. In that way, we still account for the shade competition happenning.
#
# Here is some code that reads these probabilities from the TRY database, and then computes the expected frequencies of winning and displays them in a plot :

# %%
from functionsForCalibration import *

# dictionnaryOfTraits = extract_try_traits("./ReferencesAndData/TRY data/46003.txt")
# # We remove tolerance to fire; not useful for us.
# for species in dictionnaryOfTraits.keys():
#     del dictionnaryOfTraits[species]["Species tolerance to fire"]
# print(dictionnaryOfTraits)

with open("./ReferencesAndData/Functional Traits/SpeciesTolerances.json", 'r') as file:
    dictionnaryOfTraits = json.load(file) 
# We remove tolerance to fire; not useful for us.
for species in dictionnaryOfTraits.keys():
    del dictionnaryOfTraits[species]["Species tolerance to fire"]

# # We create average values of tolerance accross the different measure of TRY,
# # using some simple and arbitrary rules to translate the different measurement systems
# # into one. See average_tolerance_traits() in functionsForCalibration.py
# averageTraitTol = average_tolerance_traits(dictionnaryOfTraits)
# print(averageTraitTol)

# We compute and plot the expected outcomes of the competition
# between each species. Rules are in plot_competition_matrices_with_shade() in
# functionsForCalibration.py
competitionDictionnary = plot_competition_matrices_with_shade(dictionnaryOfTraits)

# We export the dictionnary with the predicted probabilities to a JSON file
import json, os
if not os.path.exists("./ReferencesAndData/CompetitionOutcomes/"):
    os.mkdir("./ReferencesAndData/CompetitionOutcomes/")
with open('./ReferencesAndData/CompetitionOutcomes/competitionDictionnary.json', 'w') as f:
    json.dump(competitionDictionnary, f)

# %% [markdown]
# # DRAFTS
